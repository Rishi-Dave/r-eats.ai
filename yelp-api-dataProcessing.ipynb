# %%
import os
from dotenv import load_dotenv
import requests
import json
import pandas as pd

# %%
load_dotenv()
YELP_API_KEY = os.getenv('YELP_API_KEY')

# %%
if not YELP_API_KEY:
    print("Error: YELP_API_KEY not found in the .env file. Please ensure it's configured correctly.")
    exit()
else:
    print("Yelp API Key loaded successfully.")
# Out:
# Yelp API Key loaded successfully.

# %%
YELP_API_BASE_URL = "https://api.yelp.com/v3"

# %%
headers = {
    "Authorization": f"Bearer {YELP_API_KEY}"
}

# %%
latitude = 33.9789
longitude =  -117.32813
radius = 16093

# %%
search_params = {
    "latitude": latitude,
    "longitude": longitude,
    "radius": 16093,  # Search radius in meters (approximately 10 miles)
    "categories": "restaurants",
}

# %%
def search_all_restaurants(lat, lon, radius, categories, limit=50):
    """
    Searches for all restaurants within the given parameters, handling pagination.
    """
    businesses = []
    offset = 0
    total_fetched = 0
    max_possible = 1000  # Yelp API limit for total results in a search

    print("\nFetching all possible restaurants...")

    while total_fetched < max_possible:
        search_params = {
            "latitude": lat,
            "longitude": lon,
            "radius": radius,
            "categories": categories,
            "limit": limit,
            "offset": offset
        }
        businesses_endpoint = f"{YELP_API_BASE_URL}/businesses/search"

        try:
            response = requests.get(businesses_endpoint, headers=headers, params=search_params)
            response.raise_for_status()
            search_results = response.json()

            if search_results and 'businesses' in search_results:
                current_businesses = search_results['businesses']
                if not current_businesses:
                    print("No more restaurants found.")
                    break
                businesses.extend(current_businesses)
                total_fetched += len(current_businesses)
                print(f"Fetched {total_fetched} restaurants so far.")
                offset += limit
                if 'total' in search_results and total_fetched >= search_results['total']:
                    print("Reached total number of restaurants reported by Yelp.")
                    break
            else:
                print("Error or no businesses found in this batch.")
                break

            # Be mindful of rate limits - you might need to add a small delay here
            # time.sleep(0.1)

        except requests.exceptions.RequestException as e:
            print(f"Error during Yelp Businesses Search API request (offset {offset}): {e}")
            break

        if total_fetched >= 1000: # Hard stop at Yelp's reported max
            print("Reached Yelp's maximum of 1000 results per search.")
            break

    return businesses

# %%
all_restaurants_data = search_all_restaurants(latitude, longitude, radius, "restaurants")
# Out:
# Fetching all possible restaurants...
# Fetched 50 restaurants so far.
# Fetched 100 restaurants so far.
# Fetched 150 restaurants so far.
# Fetched 200 restaurants so far.
# Error during Yelp Businesses Search API request (offset 200): 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?latitude=33.9789&longitude=-117.32813&radius=16093&categories=restaurants&limit=50&offset=200

# %%
len(all_restaurants_data)
# Out:
# 200

# %%
if all_restaurants_data:
    restaurants_df = pd.DataFrame(all_restaurants_data)
    print("\nFirst 5 rows of the initial restaurants DataFrame:")
    print(restaurants_df.head()) 
    
else:
    restaurants_df = pd.DataFrame()
# Out:
# First 5 rows of the initial restaurants DataFrame:
#                        id                                      alias  \
# 0  7XJsjflQAnQTzvQYzAwydA   smoke-and-fire-social-eatery-riverside-2
# 1  CG0qu39ItRcAd8J5liITYQ                       elias-pita-riverside
# 2  ElH8ZbPSG1rIFA3wXyFn5Q                   the-salted-pig-riverside
# 3  KIVSXV1MrwIUO8E02M0H6Q                craving-crab-haus-riverside
# 4  wsgdv_edV5bvssYk9pyOIg  georgie-s-mediterranean-cuisine-riverside
#
#                               name  \
# 0       Smoke & Fire Social Eatery
# 1                       Elias Pita
# 2                   The Salted Pig
# 3                Craving Crab Haus
# 4  Georgie’s Mediterranean Cuisine
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/_n6TU4...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/G65RHz...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/blk-Vh...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/3WhUY5...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/smoke-and-fire-social...          2672
# 1  https://www.yelp.com/biz/elias-pita-riverside?...          1160
# 2  https://www.yelp.com/biz/the-salted-pig-rivers...          3349
# 3  https://www.yelp.com/biz/craving-crab-haus-riv...           427
# 4  https://www.yelp.com/biz/georgie-s-mediterrane...           426
#
#                                           categories  rating  \
# 0  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 1  [{'alias': 'mediterranean', 'title': 'Mediterr...     4.3
# 2  [{'alias': 'gastropubs', 'title': 'Gastropubs'...     3.8
# 3  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 4  [{'alias': 'mediterranean', 'title': 'Mediterr...     4.5
#
#                                          coordinates  \
# 0  {'latitude': 33.955971, 'longitude': -117.330408}
# 1    {'latitude': 33.97533, 'longitude': -117.34385}
# 2    {'latitude': 33.98226, 'longitude': -117.37386}
# 3    {'latitude': 33.97674, 'longitude': -117.33752}
# 4  {'latitude': 33.95623720813322, 'longitude': -...
#
#                transactions price  \
# 0                        []    $$
# 1        [delivery, pickup]    $$
# 2                [delivery]    $$
# 3  [restaurant_reservation]    $$
# 4        [delivery, pickup]    $$
#
#                                             location         phone  \
# 0  {'address1': '5225 Canyon Crest Dr', 'address2...  +19517427309
# 1  {'address1': '1490 University Ave', 'address2'...  +19516866800
# 2  {'address1': '3750 Main St', 'address2': 'Ste ...  +19517425664
# 3  {'address1': '1201 University Ave', 'address2'...  +19517425859
# 4  {'address1': '5225 Canyon Crest Dr', 'address2...  +19518230440
#
#     display_phone     distance  \
# 0  (951) 742-7309  2642.903707
# 1  (951) 686-6800  1509.822879
# 2  (951) 742-5664  4243.221458
# 3  (951) 742-5859   904.674919
# 4  (951) 823-0440  2547.020308
#
#                                       business_hours  \
# 0  [{'open': [{'is_overnight': False, 'start': '1...
# 1  [{'open': [{'is_overnight': False, 'start': '1...
# 2  [{'open': [{'is_overnight': False, 'start': '1...
# 3  [{'open': [{'is_overnight': False, 'start': '1...
# 4  [{'open': [{'is_overnight': False, 'start': '1...
#
#                                           attributes
# 0  {'business_accepts_android_pay': True, 'busine...
# 1  {'business_accepts_android_pay': True, 'busine...
# 2  {'business_accepts_android_pay': True, 'busine...
# 3  {'has_pool_table': False, 'business_url': 'htt...
# 4  {'business_url': 'https://georgiesmediterranea...

# %%
len(restaurants_df)
# Out:
# 200

# %%
def get_all_restaurant_reviews(business_id, max_reviews = 35):
    """
    Fetches all reviews for a given Yelp business ID, handling pagination.
    """
    reviews = []
    offset = 0
    total_fetched = 0
    limit_per_call = 7
    print(f"Fetching up to {max_reviews} reviews for business ID: {business_id}")
    while total_fetched < max_reviews:
        reviews_endpoint = f"{YELP_API_BASE_URL}/businesses/{business_id}/reviews"
        params = {"offset": offset}
        try:
            response = requests.get(reviews_endpoint, headers=headers, params=params)
            response.raise_for_status()
            reviews_data = response.json()
            if reviews_data and 'reviews' in reviews_data:
                current_reviews = reviews_data['reviews']
                if not current_reviews:
                    print("No more reviews found for this restaurant.")
                    break
                reviews.extend(current_reviews)
                total_fetched += len(current_reviews)
                offset += limit_per_call
                print(f"Fetched {len(reviews)} reviews so far for this restaurant.")
                if len(current_reviews) < limit_per_call:
                    print("Reached end of reviews for this restaurant.")
                    break

            else:
                print("Error or no reviews found in this batch for this restaurant.")
                break
            # Be mindful of rate limits - you might need a small delay here
            # time.sleep(0.1)
        except requests.exceptions.RequestException as e:
            print(f"Error fetching reviews for business ID {business_id} (offset {offset}): {e}")
            break
    return reviews

# %%
MAX_REVIEWS_PER_RESTAURANT = 35

# %%
all_restaurant_reviews = []
api_calls_used = 0

if not restaurants_df.empty:
    print(f"\nFetching up to {MAX_REVIEWS_PER_RESTAURANT} reviews for each restaurant (up to API call limit)...")
    for index, row in restaurants_df.iterrows():
        if api_calls_used >= 3900:  # Leave some buffer
            print("Approaching API call limit. Stopping review fetching.")
            break

        business_id = row['id']
        reviews = get_all_restaurant_reviews(business_id, max_reviews=MAX_REVIEWS_PER_RESTAURANT)
        api_calls_used += (len(reviews) // 3) + (1 if len(reviews) % 3 > 0 else 0) # Estimate API calls
        # A more precise way would be to increment the counter inside get_all_restaurant_reviews

        for review in reviews:
            review['business_id'] = business_id
            all_restaurant_reviews.append(review)

        print(f"Finished fetching reviews for restaurant ID: {business_id}. Estimated total API calls used: {api_calls_used}")

    if all_restaurant_reviews:
        reviews_df = pd.DataFrame(all_restaurant_reviews)
        print(f"\nSuccessfully fetched a total of {len(reviews_df)} reviews.")
        print("\nFirst 5 rows of the reviews DataFrame:")
        print(reviews_df.head())
    else:
        reviews_df = pd.DataFrame()
        print("No reviews fetched for the found restaurants.")
else:
    reviews_df = pd.DataFrame()
    print("No restaurants available to fetch reviews for.")
# Out:
# Fetching up to 35 reviews for each restaurant (up to API call limit)...
# Fetching up to 35 reviews for business ID: 7XJsjflQAnQTzvQYzAwydA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 7XJsjflQAnQTzvQYzAwydA. Estimated total API calls used: 1
# Fetching up to 35 reviews for business ID: CG0qu39ItRcAd8J5liITYQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: CG0qu39ItRcAd8J5liITYQ. Estimated total API calls used: 2
# Fetching up to 35 reviews for business ID: ElH8ZbPSG1rIFA3wXyFn5Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: ElH8ZbPSG1rIFA3wXyFn5Q. Estimated total API calls used: 3
# Fetching up to 35 reviews for business ID: KIVSXV1MrwIUO8E02M0H6Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: KIVSXV1MrwIUO8E02M0H6Q. Estimated total API calls used: 4
# Fetching up to 35 reviews for business ID: wsgdv_edV5bvssYk9pyOIg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: wsgdv_edV5bvssYk9pyOIg. Estimated total API calls used: 5
# Fetching up to 35 reviews for business ID: sS_qTKCEmjpUnMiToaE5_A
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: sS_qTKCEmjpUnMiToaE5_A. Estimated total API calls used: 6
# Fetching up to 35 reviews for business ID: XdEtxpf1k7KsqMf8FaJmXA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: XdEtxpf1k7KsqMf8FaJmXA. Estimated total API calls used: 7
# Fetching up to 35 reviews for business ID: 6gIcfFdEAz--Ugc2ctTK-w
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 6gIcfFdEAz--Ugc2ctTK-w. Estimated total API calls used: 8
# Fetching up to 35 reviews for business ID: apibcypiWTD4G8ZooNA8Cg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: apibcypiWTD4G8ZooNA8Cg. Estimated total API calls used: 9
# Fetching up to 35 reviews for business ID: CfKC29D6iTs1mYMk0f_KkQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: CfKC29D6iTs1mYMk0f_KkQ. Estimated total API calls used: 10
# Fetching up to 35 reviews for business ID: rUNoYQUU60Yq-bpCT0xUZQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: rUNoYQUU60Yq-bpCT0xUZQ. Estimated total API calls used: 11
# Fetching up to 35 reviews for business ID: 3xct6CRnvANgGUMrO4tcNw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 3xct6CRnvANgGUMrO4tcNw. Estimated total API calls used: 12
# Fetching up to 35 reviews for business ID: 7evtcHPkwNgsviQWsyOMbg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 7evtcHPkwNgsviQWsyOMbg. Estimated total API calls used: 13
# Fetching up to 35 reviews for business ID: AySNn4t4yfb_q0Ka6LqxZw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: AySNn4t4yfb_q0Ka6LqxZw. Estimated total API calls used: 14
# Fetching up to 35 reviews for business ID: O0N-JcIrQ-LAbjbT-1M5Sw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: O0N-JcIrQ-LAbjbT-1M5Sw. Estimated total API calls used: 15
# Fetching up to 35 reviews for business ID: q3nAiu5Tz8Xcg--PptWu_Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: q3nAiu5Tz8Xcg--PptWu_Q. Estimated total API calls used: 16
# Fetching up to 35 reviews for business ID: 03u5O8Gu8kBBhvQIGCVQXA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 03u5O8Gu8kBBhvQIGCVQXA. Estimated total API calls used: 17
# Fetching up to 35 reviews for business ID: kLqXZ-XldTzv0uTIh92Wow
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: kLqXZ-XldTzv0uTIh92Wow. Estimated total API calls used: 18
# Fetching up to 35 reviews for business ID: kvlsxh6QndtgObsa6avU8w
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: kvlsxh6QndtgObsa6avU8w. Estimated total API calls used: 19
# Fetching up to 35 reviews for business ID: EupItiepZ3S9u5rduO_Xlw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: EupItiepZ3S9u5rduO_Xlw. Estimated total API calls used: 20
# Fetching up to 35 reviews for business ID: gbSA6EdAziptUFf3acsJAQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: gbSA6EdAziptUFf3acsJAQ. Estimated total API calls used: 21
# Fetching up to 35 reviews for business ID: i1YiL9OgpGuqIxCiCSuUmQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: i1YiL9OgpGuqIxCiCSuUmQ. Estimated total API calls used: 22
# Fetching up to 35 reviews for business ID: Roowp12e9zr-Ij-uP22hgA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: Roowp12e9zr-Ij-uP22hgA. Estimated total API calls used: 23
# Fetching up to 35 reviews for business ID: OcRCjR5Cazx-SAwkTsDvOQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: OcRCjR5Cazx-SAwkTsDvOQ. Estimated total API calls used: 24
# Fetching up to 35 reviews for business ID: eY60o59C0aYrWxWGbRYu5Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: eY60o59C0aYrWxWGbRYu5Q. Estimated total API calls used: 25
# Fetching up to 35 reviews for business ID: mBrhsx7SGOy0nH8TnXQ5Rw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: mBrhsx7SGOy0nH8TnXQ5Rw. Estimated total API calls used: 26
# Fetching up to 35 reviews for business ID: 8IszWcnJ8jUUlZ_irjYP3g
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 8IszWcnJ8jUUlZ_irjYP3g. Estimated total API calls used: 27
# Fetching up to 35 reviews for business ID: oXLpNTbvdMhfGEwLId766Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: oXLpNTbvdMhfGEwLId766Q. Estimated total API calls used: 28
# Fetching up to 35 reviews for business ID: KNugA4ihbPxQjmeLm49CJA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: KNugA4ihbPxQjmeLm49CJA. Estimated total API calls used: 29
# Fetching up to 35 reviews for business ID: A98vRm8lyCOsnTvkbpkmtA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: A98vRm8lyCOsnTvkbpkmtA. Estimated total API calls used: 30
# Fetching up to 35 reviews for business ID: -fgkIMx5-ZRDUYgKvE1O9w
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: -fgkIMx5-ZRDUYgKvE1O9w. Estimated total API calls used: 31
# Fetching up to 35 reviews for business ID: MFhE3NyIfvAOOq1xHSiIzQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: MFhE3NyIfvAOOq1xHSiIzQ. Estimated total API calls used: 32
# Fetching up to 35 reviews for business ID: DXIC1pr8bZR7ZLPxZ4QhKg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: DXIC1pr8bZR7ZLPxZ4QhKg. Estimated total API calls used: 33
# Fetching up to 35 reviews for business ID: n3DreTH1a7_utHzEwVq1rg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: n3DreTH1a7_utHzEwVq1rg. Estimated total API calls used: 34
# Fetching up to 35 reviews for business ID: FQz6LM8HnVPrg4RRW_Jh8Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: FQz6LM8HnVPrg4RRW_Jh8Q. Estimated total API calls used: 35
# Fetching up to 35 reviews for business ID: cVk3td2wvKLm2J70h5cWjw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: cVk3td2wvKLm2J70h5cWjw. Estimated total API calls used: 36
# Fetching up to 35 reviews for business ID: Ra2MnPd_YbKdIUnAHDq8Ew
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: Ra2MnPd_YbKdIUnAHDq8Ew. Estimated total API calls used: 37
# Fetching up to 35 reviews for business ID: Cuy2lZrAp8qd99XH_2Caew
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: Cuy2lZrAp8qd99XH_2Caew. Estimated total API calls used: 38
# Fetching up to 35 reviews for business ID: aGMQEmRwq1eH0RQySwi3_A
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: aGMQEmRwq1eH0RQySwi3_A. Estimated total API calls used: 39
# Fetching up to 35 reviews for business ID: bJivnFC0-Ec3GlobPwg5nA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: bJivnFC0-Ec3GlobPwg5nA. Estimated total API calls used: 40
# Fetching up to 35 reviews for business ID: s97BOlt_0Vo3sPB8ofaUoA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: s97BOlt_0Vo3sPB8ofaUoA. Estimated total API calls used: 41
# Fetching up to 35 reviews for business ID: 7hwoJcWlOn9Ks2e2MKoXtw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 7hwoJcWlOn9Ks2e2MKoXtw. Estimated total API calls used: 42
# Fetching up to 35 reviews for business ID: VHMZgqDHP6o0P8xGVrFPyg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: VHMZgqDHP6o0P8xGVrFPyg. Estimated total API calls used: 43
# Fetching up to 35 reviews for business ID: 8mOvyL1Xzv2voG54DEBNog
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 8mOvyL1Xzv2voG54DEBNog. Estimated total API calls used: 44
# Fetching up to 35 reviews for business ID: oJvfAnO5XIszvpaL78XC-g
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: oJvfAnO5XIszvpaL78XC-g. Estimated total API calls used: 45
# Fetching up to 35 reviews for business ID: PcD4HzI6eqmnekgeObI5Og
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: PcD4HzI6eqmnekgeObI5Og. Estimated total API calls used: 46
# Fetching up to 35 reviews for business ID: 6wtle8H0_O5iCaZRx9lZCg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 6wtle8H0_O5iCaZRx9lZCg. Estimated total API calls used: 47
# Fetching up to 35 reviews for business ID: AdqKXJKSAJGY5jMCy3xXSg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: AdqKXJKSAJGY5jMCy3xXSg. Estimated total API calls used: 48
# Fetching up to 35 reviews for business ID: aeExI9t29e-Kpn8TZ5XmMA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: aeExI9t29e-Kpn8TZ5XmMA. Estimated total API calls used: 49
# Fetching up to 35 reviews for business ID: jC9eDzwfME8qK9XOG3kAjg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: jC9eDzwfME8qK9XOG3kAjg. Estimated total API calls used: 50
# Fetching up to 35 reviews for business ID: AdwVnfC13WvPL2_wmQVjuA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: AdwVnfC13WvPL2_wmQVjuA. Estimated total API calls used: 51
# Fetching up to 35 reviews for business ID: DPijcZdxRZ4jMT5l_HAArg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: DPijcZdxRZ4jMT5l_HAArg. Estimated total API calls used: 52
# Fetching up to 35 reviews for business ID: tzD-MFlbCZKJo-Cs31B6Ug
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: tzD-MFlbCZKJo-Cs31B6Ug. Estimated total API calls used: 53
# Fetching up to 35 reviews for business ID: ZURQMj5lImok9KYN8-3jqQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: ZURQMj5lImok9KYN8-3jqQ. Estimated total API calls used: 54
# Fetching up to 35 reviews for business ID: YaIFh5TeUD92clMFyx-gHg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: YaIFh5TeUD92clMFyx-gHg. Estimated total API calls used: 55
# Fetching up to 35 reviews for business ID: DJMTN4-z3WHD-Klvlm9ktA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: DJMTN4-z3WHD-Klvlm9ktA. Estimated total API calls used: 56
# Fetching up to 35 reviews for business ID: f-XdrGxjIbOL8pINYh-LYA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: f-XdrGxjIbOL8pINYh-LYA. Estimated total API calls used: 57
# Fetching up to 35 reviews for business ID: Mi2yziv1N-A6uQCF9DNzoQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: Mi2yziv1N-A6uQCF9DNzoQ. Estimated total API calls used: 58
# Fetching up to 35 reviews for business ID: bz5qz2-4BgC3fqV49gtwmw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: bz5qz2-4BgC3fqV49gtwmw. Estimated total API calls used: 59
# Fetching up to 35 reviews for business ID: ndKpPNChiKFlzpHgyRTjwA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: ndKpPNChiKFlzpHgyRTjwA. Estimated total API calls used: 60
# Fetching up to 35 reviews for business ID: D2kG5I5tVnm_IkH5MUN65Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: D2kG5I5tVnm_IkH5MUN65Q. Estimated total API calls used: 61
# Fetching up to 35 reviews for business ID: J5C5KKVcw0nBBRRew7E11g
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: J5C5KKVcw0nBBRRew7E11g. Estimated total API calls used: 62
# Fetching up to 35 reviews for business ID: NKdjal0ftkpA4sUWP4_yFA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: NKdjal0ftkpA4sUWP4_yFA. Estimated total API calls used: 63
# Fetching up to 35 reviews for business ID: LHXtRkqjVzntX-sBZZEkzQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: LHXtRkqjVzntX-sBZZEkzQ. Estimated total API calls used: 64
# Fetching up to 35 reviews for business ID: 0_IPUebdAJgIGRfBMjCexg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 0_IPUebdAJgIGRfBMjCexg. Estimated total API calls used: 65
# Fetching up to 35 reviews for business ID: i1tH7RmyQz2J4zxRXRqNbA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: i1tH7RmyQz2J4zxRXRqNbA. Estimated total API calls used: 66
# Fetching up to 35 reviews for business ID: sjSKCjvEdOtz_GxhqSffWA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: sjSKCjvEdOtz_GxhqSffWA. Estimated total API calls used: 67
# Fetching up to 35 reviews for business ID: NJpBe_1VhnyMZ7zhzccdgA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: NJpBe_1VhnyMZ7zhzccdgA. Estimated total API calls used: 68
# Fetching up to 35 reviews for business ID: TRI-OJfrvyZ74rtqlFSFxw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: TRI-OJfrvyZ74rtqlFSFxw. Estimated total API calls used: 69
# Fetching up to 35 reviews for business ID: Fv-gmnmnOiMjE6ZE45X4uw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: Fv-gmnmnOiMjE6ZE45X4uw. Estimated total API calls used: 70
# Fetching up to 35 reviews for business ID: ELGFg5Rs1zYtjfBNJmIwbg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: ELGFg5Rs1zYtjfBNJmIwbg. Estimated total API calls used: 71
# Fetching up to 35 reviews for business ID: s0l3TrybkqgI6RpzGCf5mQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: s0l3TrybkqgI6RpzGCf5mQ. Estimated total API calls used: 72
# Fetching up to 35 reviews for business ID: gj2Egku8gbBe00K_fxuIkw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: gj2Egku8gbBe00K_fxuIkw. Estimated total API calls used: 73
# Fetching up to 35 reviews for business ID: RPRmvthEK0z1vymZAfEUIA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: RPRmvthEK0z1vymZAfEUIA. Estimated total API calls used: 74
# Fetching up to 35 reviews for business ID: R-FeQCBgxfG7wJYOf7-Jig
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: R-FeQCBgxfG7wJYOf7-Jig. Estimated total API calls used: 75
# Fetching up to 35 reviews for business ID: 931v0-cV1uKRF48E7BdjMg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 931v0-cV1uKRF48E7BdjMg. Estimated total API calls used: 76
# Fetching up to 35 reviews for business ID: S9gwDEbJefvy4b4z4jtucQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: S9gwDEbJefvy4b4z4jtucQ. Estimated total API calls used: 77
# Fetching up to 35 reviews for business ID: CC4d284lOveSr0XCI3Wm2w
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: CC4d284lOveSr0XCI3Wm2w. Estimated total API calls used: 78
# Fetching up to 35 reviews for business ID: WkgUynDBiVejz0I-oVK3kg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: WkgUynDBiVejz0I-oVK3kg. Estimated total API calls used: 79
# Fetching up to 35 reviews for business ID: W_7FHuN2VVXGElWwxbtH_Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: W_7FHuN2VVXGElWwxbtH_Q. Estimated total API calls used: 80
# Fetching up to 35 reviews for business ID: LZlZ7odOsg4O8Kf1hZ154w
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: LZlZ7odOsg4O8Kf1hZ154w. Estimated total API calls used: 81
# Fetching up to 35 reviews for business ID: zRv04ILZOtjiV-bIZmanCg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: zRv04ILZOtjiV-bIZmanCg. Estimated total API calls used: 82
# Fetching up to 35 reviews for business ID: QvUoQUbcWJvxV-9gDjI4Sg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: QvUoQUbcWJvxV-9gDjI4Sg. Estimated total API calls used: 83
# Fetching up to 35 reviews for business ID: 05efBvIaR7_Y2hSlv85MUQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 05efBvIaR7_Y2hSlv85MUQ. Estimated total API calls used: 84
# Fetching up to 35 reviews for business ID: HW7U_HnqX7CVKOzEayb5QQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: HW7U_HnqX7CVKOzEayb5QQ. Estimated total API calls used: 85
# Fetching up to 35 reviews for business ID: y4QgBov56rpzs-GlUxRXnQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: y4QgBov56rpzs-GlUxRXnQ. Estimated total API calls used: 86
# Fetching up to 35 reviews for business ID: lTxs9mQCyKTPKX42ndVp5w
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: lTxs9mQCyKTPKX42ndVp5w. Estimated total API calls used: 87
# Fetching up to 35 reviews for business ID: 9FFs6tEJ4QI_fc1fA2QYEw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 9FFs6tEJ4QI_fc1fA2QYEw. Estimated total API calls used: 88
# Fetching up to 35 reviews for business ID: of3e_zx1h9xfN0XQR_jPkg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: of3e_zx1h9xfN0XQR_jPkg. Estimated total API calls used: 89
# Fetching up to 35 reviews for business ID: 78JHPmmemAKAynduy5OpBw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 78JHPmmemAKAynduy5OpBw. Estimated total API calls used: 90
# Fetching up to 35 reviews for business ID: huT_xjIvpzkBylXhzRgnXw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: huT_xjIvpzkBylXhzRgnXw. Estimated total API calls used: 91
# Fetching up to 35 reviews for business ID: X6raIHQbHLceXIMmLgnAmw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: X6raIHQbHLceXIMmLgnAmw. Estimated total API calls used: 92
# Fetching up to 35 reviews for business ID: eZEZBhD-rugW1rry4om04g
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: eZEZBhD-rugW1rry4om04g. Estimated total API calls used: 93
# Fetching up to 35 reviews for business ID: wkSus57ryqnskusy4HdHUA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: wkSus57ryqnskusy4HdHUA. Estimated total API calls used: 94
# Fetching up to 35 reviews for business ID: VZoh71NAOcCRvWWKtc3l2w
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: VZoh71NAOcCRvWWKtc3l2w. Estimated total API calls used: 95
# Fetching up to 35 reviews for business ID: l_dAHpFwN_1oZy_w_1jXpQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: l_dAHpFwN_1oZy_w_1jXpQ. Estimated total API calls used: 96
# Fetching up to 35 reviews for business ID: y9nwVJv4JWyHoRCS9In3ig
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: y9nwVJv4JWyHoRCS9In3ig. Estimated total API calls used: 97
# Fetching up to 35 reviews for business ID: Kyl8FU4ZIT9AgLxuMwJ7fw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: Kyl8FU4ZIT9AgLxuMwJ7fw. Estimated total API calls used: 98
# Fetching up to 35 reviews for business ID: YEaRyuM0eaP--6VtHf3vXQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: YEaRyuM0eaP--6VtHf3vXQ. Estimated total API calls used: 99
# Fetching up to 35 reviews for business ID: g3d3dEhH5vaHrnCLbMXi_Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: g3d3dEhH5vaHrnCLbMXi_Q. Estimated total API calls used: 100
# Fetching up to 35 reviews for business ID: 47EekrncZPXESWmfh0yW1Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 47EekrncZPXESWmfh0yW1Q. Estimated total API calls used: 101
# Fetching up to 35 reviews for business ID: 5a9eTcrnzcbEoEEHv6MKvA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 5a9eTcrnzcbEoEEHv6MKvA. Estimated total API calls used: 102
# Fetching up to 35 reviews for business ID: Xwf4hIuPdvog0ZsnhmpuJw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: Xwf4hIuPdvog0ZsnhmpuJw. Estimated total API calls used: 103
# Fetching up to 35 reviews for business ID: bg7_ljsA9dgivKu5oK-BuQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: bg7_ljsA9dgivKu5oK-BuQ. Estimated total API calls used: 104
# Fetching up to 35 reviews for business ID: RPGO99muEym2cEbxleV8rQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: RPGO99muEym2cEbxleV8rQ. Estimated total API calls used: 105
# Fetching up to 35 reviews for business ID: _Y_RXxv-8ohhxfqTjpEZMw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: _Y_RXxv-8ohhxfqTjpEZMw. Estimated total API calls used: 106
# Fetching up to 35 reviews for business ID: lDsv-51s0y1woKW-6yW7Lg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: lDsv-51s0y1woKW-6yW7Lg. Estimated total API calls used: 107
# Fetching up to 35 reviews for business ID: dfIwydGaF9pf80H0WK0-oA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: dfIwydGaF9pf80H0WK0-oA. Estimated total API calls used: 108
# Fetching up to 35 reviews for business ID: AycusHkcJ41DtY7bzjvXeA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: AycusHkcJ41DtY7bzjvXeA. Estimated total API calls used: 109
# Fetching up to 35 reviews for business ID: 8JoX9SXgG0LQhyF9BWJaGg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 8JoX9SXgG0LQhyF9BWJaGg. Estimated total API calls used: 110
# Fetching up to 35 reviews for business ID: 8nykSwzrfHDGUSbYal67Yg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 8nykSwzrfHDGUSbYal67Yg. Estimated total API calls used: 111
# Fetching up to 35 reviews for business ID: 7xz-KIcPe0lUUgWxRFU2eA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 7xz-KIcPe0lUUgWxRFU2eA. Estimated total API calls used: 112
# Fetching up to 35 reviews for business ID: 4QP6TcX2abe5Lvfvz2i1Tw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 4QP6TcX2abe5Lvfvz2i1Tw. Estimated total API calls used: 113
# Fetching up to 35 reviews for business ID: IGlONAZbRgP6hW1CR16tvA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: IGlONAZbRgP6hW1CR16tvA. Estimated total API calls used: 114
# Fetching up to 35 reviews for business ID: cOlSiUEKC8kPPx2Uq4edsA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: cOlSiUEKC8kPPx2Uq4edsA. Estimated total API calls used: 115
# Fetching up to 35 reviews for business ID: FZAZeyLrkkj6JGAJUSa4nw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: FZAZeyLrkkj6JGAJUSa4nw. Estimated total API calls used: 116
# Fetching up to 35 reviews for business ID: q0sXmZcWpsBFmUJkkMhCSA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: q0sXmZcWpsBFmUJkkMhCSA. Estimated total API calls used: 117
# Fetching up to 35 reviews for business ID: jIljAnW4XxyA1NsctjE-1Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: jIljAnW4XxyA1NsctjE-1Q. Estimated total API calls used: 118
# Fetching up to 35 reviews for business ID: 2ap-ZmxBxkMjxonfYZGw9w
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 2ap-ZmxBxkMjxonfYZGw9w. Estimated total API calls used: 119
# Fetching up to 35 reviews for business ID: RDrDCLyQKFUpTqIsZPBy5g
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: RDrDCLyQKFUpTqIsZPBy5g. Estimated total API calls used: 120
# Fetching up to 35 reviews for business ID: 6Wvvv634l173k4GObJcYAA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 6Wvvv634l173k4GObJcYAA. Estimated total API calls used: 121
# Fetching up to 35 reviews for business ID: AksEKVqAv3H1A3TEF-SCLg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: AksEKVqAv3H1A3TEF-SCLg. Estimated total API calls used: 122
# Fetching up to 35 reviews for business ID: L8LBM7fTG2F_GdqoVazsZQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: L8LBM7fTG2F_GdqoVazsZQ. Estimated total API calls used: 123
# Fetching up to 35 reviews for business ID: -ykWYecvGothlzB1kNsUgA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: -ykWYecvGothlzB1kNsUgA. Estimated total API calls used: 124
# Fetching up to 35 reviews for business ID: ha4cHYcVyKPtzM1dG4_Whg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: ha4cHYcVyKPtzM1dG4_Whg. Estimated total API calls used: 125
# Fetching up to 35 reviews for business ID: fEJdPArd5m2wMHq7ZOChPw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: fEJdPArd5m2wMHq7ZOChPw. Estimated total API calls used: 126
# Fetching up to 35 reviews for business ID: wnnQNdPxOQVPDjxYMyS96A
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: wnnQNdPxOQVPDjxYMyS96A. Estimated total API calls used: 127
# Fetching up to 35 reviews for business ID: bjN0MCipb5d9Y6ae9UmeUw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: bjN0MCipb5d9Y6ae9UmeUw. Estimated total API calls used: 128
# Fetching up to 35 reviews for business ID: SV0xnSnq2jLCm3EzB3l0yg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: SV0xnSnq2jLCm3EzB3l0yg. Estimated total API calls used: 129
# Fetching up to 35 reviews for business ID: RmCIhHu5XowEghL0szZXkA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: RmCIhHu5XowEghL0szZXkA. Estimated total API calls used: 130
# Fetching up to 35 reviews for business ID: JaRO8X9sd79iIEyWD9s0oQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: JaRO8X9sd79iIEyWD9s0oQ. Estimated total API calls used: 131
# Fetching up to 35 reviews for business ID: B1cob7u-MrNYnxkEPekmLw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: B1cob7u-MrNYnxkEPekmLw. Estimated total API calls used: 132
# Fetching up to 35 reviews for business ID: N6OAFpCd1YgXpFndbr0K3g
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: N6OAFpCd1YgXpFndbr0K3g. Estimated total API calls used: 133
# Fetching up to 35 reviews for business ID: Yqg_3JIhqR04A-WKTk8dyw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: Yqg_3JIhqR04A-WKTk8dyw. Estimated total API calls used: 134
# Fetching up to 35 reviews for business ID: cRd2SfAdbbFlhFvKrjVG3Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: cRd2SfAdbbFlhFvKrjVG3Q. Estimated total API calls used: 135
# Fetching up to 35 reviews for business ID: 4LdcFmyIPhbkQM_3uRYafA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 4LdcFmyIPhbkQM_3uRYafA. Estimated total API calls used: 136
# Fetching up to 35 reviews for business ID: 9xh-2nhv7Eb0vshqMkgMVw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 9xh-2nhv7Eb0vshqMkgMVw. Estimated total API calls used: 137
# Fetching up to 35 reviews for business ID: PkWdkxqhTucju1nUruj_Rw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: PkWdkxqhTucju1nUruj_Rw. Estimated total API calls used: 138
# Fetching up to 35 reviews for business ID: XTSx0NpZwjYbpW1MgFzVdA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: XTSx0NpZwjYbpW1MgFzVdA. Estimated total API calls used: 139
# Fetching up to 35 reviews for business ID: RAmHQ1bJMZ6YMzqzK7r9Zg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: RAmHQ1bJMZ6YMzqzK7r9Zg. Estimated total API calls used: 140
# Fetching up to 35 reviews for business ID: jG3tg15mgnVxUWUfmQl2jQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: jG3tg15mgnVxUWUfmQl2jQ. Estimated total API calls used: 141
# Fetching up to 35 reviews for business ID: z5Le45u8GcXstjhp_tj0VQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: z5Le45u8GcXstjhp_tj0VQ. Estimated total API calls used: 142
# Fetching up to 35 reviews for business ID: R8PH35XP9Hci80liJ5tqhA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: R8PH35XP9Hci80liJ5tqhA. Estimated total API calls used: 143
# Fetching up to 35 reviews for business ID: l6XX8Io0Q6exEWZNla9KnA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: l6XX8Io0Q6exEWZNla9KnA. Estimated total API calls used: 144
# Fetching up to 35 reviews for business ID: KM24v-oPJiJuTQQ7s7aq-g
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: KM24v-oPJiJuTQQ7s7aq-g. Estimated total API calls used: 145
# Fetching up to 35 reviews for business ID: xEDNdmEi6jQ1eF1pv2EzuQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: xEDNdmEi6jQ1eF1pv2EzuQ. Estimated total API calls used: 146
# Fetching up to 35 reviews for business ID: iS6E6Ue2bGMWjLARoNUkkg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: iS6E6Ue2bGMWjLARoNUkkg. Estimated total API calls used: 147
# Fetching up to 35 reviews for business ID: IyvTC0XbOd0szRd7GXt6EA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: IyvTC0XbOd0szRd7GXt6EA. Estimated total API calls used: 148
# Fetching up to 35 reviews for business ID: qNZoljRYA7srJvq3up5-bA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: qNZoljRYA7srJvq3up5-bA. Estimated total API calls used: 149
# Fetching up to 35 reviews for business ID: KxLULkR5-8YRm_5xfZuHeA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: KxLULkR5-8YRm_5xfZuHeA. Estimated total API calls used: 150
# Fetching up to 35 reviews for business ID: tt1e_ig_YJ8WfscCpqx5xA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: tt1e_ig_YJ8WfscCpqx5xA. Estimated total API calls used: 151
# Fetching up to 35 reviews for business ID: Q6V0_hM9mAAT640nKn6k1Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: Q6V0_hM9mAAT640nKn6k1Q. Estimated total API calls used: 152
# Fetching up to 35 reviews for business ID: QmHRCX0C7UojvMRY7dXrwQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: QmHRCX0C7UojvMRY7dXrwQ. Estimated total API calls used: 153
# Fetching up to 35 reviews for business ID: 70R5P627XobWlaK86b51XQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 70R5P627XobWlaK86b51XQ. Estimated total API calls used: 154
# Fetching up to 35 reviews for business ID: 2xm4JBOsQtgYCU3tWLZ5Qw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 2xm4JBOsQtgYCU3tWLZ5Qw. Estimated total API calls used: 155
# Fetching up to 35 reviews for business ID: HWH7eE5T3yGryKKYK0abxg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: HWH7eE5T3yGryKKYK0abxg. Estimated total API calls used: 156
# Fetching up to 35 reviews for business ID: iRGXxFx1lmUE8K9XUJ2rVg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: iRGXxFx1lmUE8K9XUJ2rVg. Estimated total API calls used: 157
# Fetching up to 35 reviews for business ID: 4cEDOjYCDnbLl6zYzfhcOQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 4cEDOjYCDnbLl6zYzfhcOQ. Estimated total API calls used: 158
# Fetching up to 35 reviews for business ID: m5KA_BhRcJXzXHWcGhDy9g
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: m5KA_BhRcJXzXHWcGhDy9g. Estimated total API calls used: 159
# Fetching up to 35 reviews for business ID: JU1dqNsJnboA-HEtH5kEgA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: JU1dqNsJnboA-HEtH5kEgA. Estimated total API calls used: 160
# Fetching up to 35 reviews for business ID: BFZVfjzpY5bbQrvhE9qiuQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: BFZVfjzpY5bbQrvhE9qiuQ. Estimated total API calls used: 161
# Fetching up to 35 reviews for business ID: NOIboRSx7u8ivBcSadEb1g
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: NOIboRSx7u8ivBcSadEb1g. Estimated total API calls used: 162
# Fetching up to 35 reviews for business ID: FyVjW7ja75YztmyOULb9Ow
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: FyVjW7ja75YztmyOULb9Ow. Estimated total API calls used: 163
# Fetching up to 35 reviews for business ID: ePuI2NkmCCAzOYxjjTOTPA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: ePuI2NkmCCAzOYxjjTOTPA. Estimated total API calls used: 164
# Fetching up to 35 reviews for business ID: 93chG0AbzI0T-T5bBxmFCQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 93chG0AbzI0T-T5bBxmFCQ. Estimated total API calls used: 165
# Fetching up to 35 reviews for business ID: yL5l6upsvcjxmirajfPsIw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: yL5l6upsvcjxmirajfPsIw. Estimated total API calls used: 166
# Fetching up to 35 reviews for business ID: dJi3eGUiCnYAFyKBvAqCfw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: dJi3eGUiCnYAFyKBvAqCfw. Estimated total API calls used: 167
# Fetching up to 35 reviews for business ID: aMlLb3DA_eFuEA-V-oK8Eg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: aMlLb3DA_eFuEA-V-oK8Eg. Estimated total API calls used: 168
# Fetching up to 35 reviews for business ID: HzBlxzhZ4ynLZKll8JpT5A
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: HzBlxzhZ4ynLZKll8JpT5A. Estimated total API calls used: 169
# Fetching up to 35 reviews for business ID: A8X3UZZCVMBbCv7TXo_i3Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: A8X3UZZCVMBbCv7TXo_i3Q. Estimated total API calls used: 170
# Fetching up to 35 reviews for business ID: QnGovHtjHq98IxcGgef03g
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: QnGovHtjHq98IxcGgef03g. Estimated total API calls used: 171
# Fetching up to 35 reviews for business ID: onhXOZkoMLCxZTEYWXT0og
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: onhXOZkoMLCxZTEYWXT0og. Estimated total API calls used: 172
# Fetching up to 35 reviews for business ID: ybYXQgWBs2Y7iNRY_RRWeA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: ybYXQgWBs2Y7iNRY_RRWeA. Estimated total API calls used: 173
# Fetching up to 35 reviews for business ID: JRMsvhKE2Ea6QZvUZCOMBQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: JRMsvhKE2Ea6QZvUZCOMBQ. Estimated total API calls used: 174
# Fetching up to 35 reviews for business ID: gOgAA5JPE0ncLqBxHuFmLw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: gOgAA5JPE0ncLqBxHuFmLw. Estimated total API calls used: 175
# Fetching up to 35 reviews for business ID: BgTPaEwZg4AclTYI2-kYEw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: BgTPaEwZg4AclTYI2-kYEw. Estimated total API calls used: 176
# Fetching up to 35 reviews for business ID: yZpPkAd0zofvTSZGSh4xnw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: yZpPkAd0zofvTSZGSh4xnw. Estimated total API calls used: 177
# Fetching up to 35 reviews for business ID: fhRAPevCY6HZayKFyk0NAw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: fhRAPevCY6HZayKFyk0NAw. Estimated total API calls used: 178
# Fetching up to 35 reviews for business ID: nTKVqG0uYmC5J435eUuYKw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: nTKVqG0uYmC5J435eUuYKw. Estimated total API calls used: 179
# Fetching up to 35 reviews for business ID: NuILxqWXBD7jg5SRX-kMQA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: NuILxqWXBD7jg5SRX-kMQA. Estimated total API calls used: 180
# Fetching up to 35 reviews for business ID: na8kJ2ecDBYghMIsXWDO_A
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: na8kJ2ecDBYghMIsXWDO_A. Estimated total API calls used: 181
# Fetching up to 35 reviews for business ID: 1bST6eFWDoziRKHPo6ySuQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 1bST6eFWDoziRKHPo6ySuQ. Estimated total API calls used: 182
# Fetching up to 35 reviews for business ID: 4mKhbX5p78-O6Bd3FdwI7w
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 4mKhbX5p78-O6Bd3FdwI7w. Estimated total API calls used: 183
# Fetching up to 35 reviews for business ID: zr0mew-Z0KWTMrV3CN8sWg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: zr0mew-Z0KWTMrV3CN8sWg. Estimated total API calls used: 184
# Fetching up to 35 reviews for business ID: GT6xRTF-N-CYRvjMubijiw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: GT6xRTF-N-CYRvjMubijiw. Estimated total API calls used: 185
# Fetching up to 35 reviews for business ID: FUAlDRAjTUuRdu_MFHhPtw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: FUAlDRAjTUuRdu_MFHhPtw. Estimated total API calls used: 186
# Fetching up to 35 reviews for business ID: klWsyAabWHfJgurV2AAGqQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: klWsyAabWHfJgurV2AAGqQ. Estimated total API calls used: 187
# Fetching up to 35 reviews for business ID: qwxBRWbi35V_5HUwNu9Q4Q
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: qwxBRWbi35V_5HUwNu9Q4Q. Estimated total API calls used: 188
# Fetching up to 35 reviews for business ID: CoxyYow7XGAbQv8rmwTvFw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: CoxyYow7XGAbQv8rmwTvFw. Estimated total API calls used: 189
# Fetching up to 35 reviews for business ID: -yI56RgpK7CDAOLGwz4MsA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: -yI56RgpK7CDAOLGwz4MsA. Estimated total API calls used: 190
# Fetching up to 35 reviews for business ID: 6plea3htDMlCQ2-sKU0e-A
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 6plea3htDMlCQ2-sKU0e-A. Estimated total API calls used: 191
# Fetching up to 35 reviews for business ID: WprmkCqS4-TGdDjCtikAdw
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: WprmkCqS4-TGdDjCtikAdw. Estimated total API calls used: 192
# Fetching up to 35 reviews for business ID: 9cYljLELx0bk246u58G1ig
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: 9cYljLELx0bk246u58G1ig. Estimated total API calls used: 193
# Fetching up to 35 reviews for business ID: J5rTfWdl3LXuLQSBasojRg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: J5rTfWdl3LXuLQSBasojRg. Estimated total API calls used: 194
# Fetching up to 35 reviews for business ID: q_BTLHFAMle0409zHSV44g
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: q_BTLHFAMle0409zHSV44g. Estimated total API calls used: 195
# Fetching up to 35 reviews for business ID: MSOiTVW_BX7PRwC2ZNQuTA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: MSOiTVW_BX7PRwC2ZNQuTA. Estimated total API calls used: 196
# Fetching up to 35 reviews for business ID: zUwmI-0nRFWP_ifwxZfNNg
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: zUwmI-0nRFWP_ifwxZfNNg. Estimated total API calls used: 197
# Fetching up to 35 reviews for business ID: rPCS9_-kXx4FOBVyBiw_IQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: rPCS9_-kXx4FOBVyBiw_IQ. Estimated total API calls used: 198
# Fetching up to 35 reviews for business ID: bMKxq1N2jtl1fIz38GU4aA
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: bMKxq1N2jtl1fIz38GU4aA. Estimated total API calls used: 199
# Fetching up to 35 reviews for business ID: kmdrAFVh0A82ZH8aFoZdAQ
# Fetched 3 reviews so far for this restaurant.
# Reached end of reviews for this restaurant.
# Finished fetching reviews for restaurant ID: kmdrAFVh0A82ZH8aFoZdAQ. Estimated total API calls used: 200
#
# Successfully fetched a total of 600 reviews.
#
# First 5 rows of the reviews DataFrame:
#                        id                                                url  \
# 0  e84DJb5bqU63D-7cObU4pQ  https://www.yelp.com/biz/smoke-and-fire-social...
# 1  rWQ-KpfjLDTBes6LarDuhg  https://www.yelp.com/biz/smoke-and-fire-social...
# 2  O3Rnl2Ew8uulDA_TBPTDtA  https://www.yelp.com/biz/smoke-and-fire-social...
# 3  UV3u1IbW-q38XWgTZgRdnQ  https://www.yelp.com/biz/elias-pita-riverside?...
# 4  43QScRvU-r0NLjt-dzG5WQ  https://www.yelp.com/biz/elias-pita-riverside?...
#
#                                                 text  rating  \
# 0  Food was good, service was great, Alexa was ve...       4
# 1  Absolutely love the atmosphere and the food is...       5
# 2  They ran out of fries and coleslaw and still c...       3
# 3  Excellent + food was delicious, great portion,...       5
# 4  The food was amazing! We had the gyro's and hu...       5
#
#           time_created                                               user  \
# 0  2025-04-05 12:27:18  {'id': 'KcxN-hBjh7OsdQJh_0xvWA', 'profile_url'...
# 1  2025-03-23 21:16:35  {'id': 'DJDC7kwj4qItmsi5BXWC8A', 'profile_url'...
# 2  2025-03-03 03:39:00  {'id': 'S3gYxVAwJcGy76e3gdJZBg', 'profile_url'...
# 3  2025-04-06 11:01:58  {'id': 'kQKosEedp_QFSZS7wyB3Og', 'profile_url'...
# 4  2024-11-08 15:17:32  {'id': 'ORK17DiBQHAmLYdEjzsnJQ', 'profile_url'...
#
#               business_id
# 0  7XJsjflQAnQTzvQYzAwydA
# 1  7XJsjflQAnQTzvQYzAwydA
# 2  7XJsjflQAnQTzvQYzAwydA
# 3  CG0qu39ItRcAd8J5liITYQ
# 4  CG0qu39ItRcAd8J5liITYQ

# %%
print("Columns in restaurants_df:")
print(restaurants_df.columns)
print("\nColumns in restaurant_reviews_df:")
print(restaurant_reviews_df.columns)
# Out:
# Columns in restaurants_df:
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'coordinates', 'transactions', 'price',
#        'location', 'phone', 'display_phone', 'distance', 'business_hours',
#        'attributes'],
#       dtype='object')
#
# Columns in restaurant_reviews_df:
# Index(['id_x', 'alias', 'name', 'image_url', 'is_closed', 'url_x',
#        'review_count', 'categories', 'rating_x', 'coordinates', 'transactions',
#        'price', 'location', 'phone', 'display_phone', 'distance',
#        'business_hours', 'attributes', 'id_y', 'url_y', 'text', 'rating_y',
#        'time_created', 'user', 'business_id'],
#       dtype='object')

# %%
reviews_df.head()
# Out:
#                        id                                                url  \
# 0  e84DJb5bqU63D-7cObU4pQ  https://www.yelp.com/biz/smoke-and-fire-social...
# 1  rWQ-KpfjLDTBes6LarDuhg  https://www.yelp.com/biz/smoke-and-fire-social...
# 2  O3Rnl2Ew8uulDA_TBPTDtA  https://www.yelp.com/biz/smoke-and-fire-social...
# 3  UV3u1IbW-q38XWgTZgRdnQ  https://www.yelp.com/biz/elias-pita-riverside?...
# 4  43QScRvU-r0NLjt-dzG5WQ  https://www.yelp.com/biz/elias-pita-riverside?...
#
#                                                 text  rating  \
# 0  Food was good, service was great, Alexa was ve...       4
# 1  Absolutely love the atmosphere and the food is...       5
# 2  They ran out of fries and coleslaw and still c...       3
# 3  Excellent + food was delicious, great portion,...       5
# 4  The food was amazing! We had the gyro's and hu...       5
#
#           time_created                                               user  \
# 0  2025-04-05 12:27:18  {'id': 'KcxN-hBjh7OsdQJh_0xvWA', 'profile_url'...
# 1  2025-03-23 21:16:35  {'id': 'DJDC7kwj4qItmsi5BXWC8A', 'profile_url'...
# 2  2025-03-03 03:39:00  {'id': 'S3gYxVAwJcGy76e3gdJZBg', 'profile_url'...
# 3  2025-04-06 11:01:58  {'id': 'kQKosEedp_QFSZS7wyB3Og', 'profile_url'...
# 4  2024-11-08 15:17:32  {'id': 'ORK17DiBQHAmLYdEjzsnJQ', 'profile_url'...
#
#               business_id
# 0  7XJsjflQAnQTzvQYzAwydA
# 1  7XJsjflQAnQTzvQYzAwydA
# 2  7XJsjflQAnQTzvQYzAwydA
# 3  CG0qu39ItRcAd8J5liITYQ
# 4  CG0qu39ItRcAd8J5liITYQ

# %%
if not restaurants_df.empty and not reviews_df.empty:
    restaurant_reviews_df = pd.merge(restaurants_df, reviews_df, left_on='id', right_on='business_id', how='inner')
    print(f"\nMerged DataFrame shape: {restaurant_reviews_df.shape}")
    print("\nFirst 5 rows of the merged DataFrame:")
    print(restaurant_reviews_df.head())
else:
    restaurant_reviews_df = pd.DataFrame()
    print("\nCould not merge restaurant and review data as one or both DataFrames are empty.")
# Out:
# Merged DataFrame shape: (600, 25)
#
# First 5 rows of the merged DataFrame:
#                      id_x                                     alias  \
# 0  7XJsjflQAnQTzvQYzAwydA  smoke-and-fire-social-eatery-riverside-2
# 1  7XJsjflQAnQTzvQYzAwydA  smoke-and-fire-social-eatery-riverside-2
# 2  7XJsjflQAnQTzvQYzAwydA  smoke-and-fire-social-eatery-riverside-2
# 3  CG0qu39ItRcAd8J5liITYQ                      elias-pita-riverside
# 4  CG0qu39ItRcAd8J5liITYQ                      elias-pita-riverside
#
#                          name  \
# 0  Smoke & Fire Social Eatery
# 1  Smoke & Fire Social Eatery
# 2  Smoke & Fire Social Eatery
# 3                  Elias Pita
# 4                  Elias Pita
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/_n6TU4...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/_n6TU4...      False
#
#                                                url_x  review_count  \
# 0  https://www.yelp.com/biz/smoke-and-fire-social...          2672
# 1  https://www.yelp.com/biz/smoke-and-fire-social...          2672
# 2  https://www.yelp.com/biz/smoke-and-fire-social...          2672
# 3  https://www.yelp.com/biz/elias-pita-riverside?...          1160
# 4  https://www.yelp.com/biz/elias-pita-riverside?...          1160
#
#                                           categories  rating_x  \
# 0  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...       4.5
# 1  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...       4.5
# 2  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...       4.5
# 3  [{'alias': 'mediterranean', 'title': 'Mediterr...       4.3
# 4  [{'alias': 'mediterranean', 'title': 'Mediterr...       4.3
#
#                                          coordinates  ...     distance  \
# 0  {'latitude': 33.955971, 'longitude': -117.330408}  ...  2642.903707
# 1  {'latitude': 33.955971, 'longitude': -117.330408}  ...  2642.903707
# 2  {'latitude': 33.955971, 'longitude': -117.330408}  ...  2642.903707
# 3    {'latitude': 33.97533, 'longitude': -117.34385}  ...  1509.822879
# 4    {'latitude': 33.97533, 'longitude': -117.34385}  ...  1509.822879
#
#                                       business_hours  \
# 0  [{'open': [{'is_overnight': False, 'start': '1...
# 1  [{'open': [{'is_overnight': False, 'start': '1...
# 2  [{'open': [{'is_overnight': False, 'start': '1...
# 3  [{'open': [{'is_overnight': False, 'start': '1...
# 4  [{'open': [{'is_overnight': False, 'start': '1...
#
#                                           attributes                    id_y  \
# 0  {'business_accepts_android_pay': True, 'busine...  e84DJb5bqU63D-7cObU4pQ
# 1  {'business_accepts_android_pay': True, 'busine...  rWQ-KpfjLDTBes6LarDuhg
# 2  {'business_accepts_android_pay': True, 'busine...  O3Rnl2Ew8uulDA_TBPTDtA
# 3  {'business_accepts_android_pay': True, 'busine...  UV3u1IbW-q38XWgTZgRdnQ
# 4  {'business_accepts_android_pay': True, 'busine...  43QScRvU-r0NLjt-dzG5WQ
#
#                                                url_y  \
# 0  https://www.yelp.com/biz/smoke-and-fire-social...
# 1  https://www.yelp.com/biz/smoke-and-fire-social...
# 2  https://www.yelp.com/biz/smoke-and-fire-social...
# 3  https://www.yelp.com/biz/elias-pita-riverside?...
# 4  https://www.yelp.com/biz/elias-pita-riverside?...
#
#                                                 text rating_y  \
# 0  Food was good, service was great, Alexa was ve...        4
# 1  Absolutely love the atmosphere and the food is...        5
# 2  They ran out of fries and coleslaw and still c...        3
# 3  Excellent + food was delicious, great portion,...        5
# 4  The food was amazing! We had the gyro's and hu...        5
#
#           time_created                                               user  \
# 0  2025-04-05 12:27:18  {'id': 'KcxN-hBjh7OsdQJh_0xvWA', 'profile_url'...
# 1  2025-03-23 21:16:35  {'id': 'DJDC7kwj4qItmsi5BXWC8A', 'profile_url'...
# 2  2025-03-03 03:39:00  {'id': 'S3gYxVAwJcGy76e3gdJZBg', 'profile_url'...
# 3  2025-04-06 11:01:58  {'id': 'kQKosEedp_QFSZS7wyB3Og', 'profile_url'...
# 4  2024-11-08 15:17:32  {'id': 'ORK17DiBQHAmLYdEjzsnJQ', 'profile_url'...
#
#               business_id
# 0  7XJsjflQAnQTzvQYzAwydA
# 1  7XJsjflQAnQTzvQYzAwydA
# 2  7XJsjflQAnQTzvQYzAwydA
# 3  CG0qu39ItRcAd8J5liITYQ
# 4  CG0qu39ItRcAd8J5liITYQ
#
# [5 rows x 25 columns]

# %%
if not restaurant_reviews_df.empty:
    restaurant_reviews_final_df = restaurant_reviews_df[[
        'id_x',  # Business ID
        'name',
        'categories',  # Restaurant Categories
        'location',
        'coordinates',
        'rating_x',  # Average Rating
        'id_y',  # Review ID
        'user',
        'rating_y',  # Review Rating
        'text',  # Review Text
        'time_created'
    ]].copy()
    restaurant_reviews_final_df.rename(columns={
        'id_x': 'business_id',
        'categories': 'categories',
        'rating_x': 'avg_rating',
        'rating_y': 'review_rating',
        'text': 'review_text',
        'time_created': 'review_date',
        'id_y': 'review_id'
    }, inplace=True)
    print("\nFirst 5 rows of the final combined DataFrame:")
    print(restaurant_reviews_final_df.head())
else:
    print("\nFinal combined DataFrame is empty.")
# Out:
# First 5 rows of the final combined DataFrame:
#               business_id                        name  \
# 0  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 1  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 2  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 3  CG0qu39ItRcAd8J5liITYQ                  Elias Pita
# 4  CG0qu39ItRcAd8J5liITYQ                  Elias Pita
#
#                                           categories  \
# 0  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 1  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 2  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 3  [{'alias': 'mediterranean', 'title': 'Mediterr...
# 4  [{'alias': 'mediterranean', 'title': 'Mediterr...
#
#                                             location  \
# 0  {'address1': '5225 Canyon Crest Dr', 'address2...
# 1  {'address1': '5225 Canyon Crest Dr', 'address2...
# 2  {'address1': '5225 Canyon Crest Dr', 'address2...
# 3  {'address1': '1490 University Ave', 'address2'...
# 4  {'address1': '1490 University Ave', 'address2'...
#
#                                          coordinates  avg_rating  \
# 0  {'latitude': 33.955971, 'longitude': -117.330408}         4.5
# 1  {'latitude': 33.955971, 'longitude': -117.330408}         4.5
# 2  {'latitude': 33.955971, 'longitude': -117.330408}         4.5
# 3    {'latitude': 33.97533, 'longitude': -117.34385}         4.3
# 4    {'latitude': 33.97533, 'longitude': -117.34385}         4.3
#
#                 review_id                                               user  \
# 0  e84DJb5bqU63D-7cObU4pQ  {'id': 'KcxN-hBjh7OsdQJh_0xvWA', 'profile_url'...
# 1  rWQ-KpfjLDTBes6LarDuhg  {'id': 'DJDC7kwj4qItmsi5BXWC8A', 'profile_url'...
# 2  O3Rnl2Ew8uulDA_TBPTDtA  {'id': 'S3gYxVAwJcGy76e3gdJZBg', 'profile_url'...
# 3  UV3u1IbW-q38XWgTZgRdnQ  {'id': 'kQKosEedp_QFSZS7wyB3Og', 'profile_url'...
# 4  43QScRvU-r0NLjt-dzG5WQ  {'id': 'ORK17DiBQHAmLYdEjzsnJQ', 'profile_url'...
#
#    review_rating                                        review_text  \
# 0              4  Food was good, service was great, Alexa was ve...
# 1              5  Absolutely love the atmosphere and the food is...
# 2              3  They ran out of fries and coleslaw and still c...
# 3              5  Excellent + food was delicious, great portion,...
# 4              5  The food was amazing! We had the gyro's and hu...
#
#            review_date
# 0  2025-04-05 12:27:18
# 1  2025-03-23 21:16:35
# 2  2025-03-03 03:39:00
# 3  2025-04-06 11:01:58
# 4  2024-11-08 15:17:32

# %%
restaurant_reviews_final_df.head()
# Out:
#               business_id                        name  \
# 0  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 1  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 2  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 3  CG0qu39ItRcAd8J5liITYQ                  Elias Pita
# 4  CG0qu39ItRcAd8J5liITYQ                  Elias Pita
#
#                                           categories  \
# 0  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 1  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 2  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 3  [{'alias': 'mediterranean', 'title': 'Mediterr...
# 4  [{'alias': 'mediterranean', 'title': 'Mediterr...
#
#                                             location  \
# 0  {'address1': '5225 Canyon Crest Dr', 'address2...
# 1  {'address1': '5225 Canyon Crest Dr', 'address2...
# 2  {'address1': '5225 Canyon Crest Dr', 'address2...
# 3  {'address1': '1490 University Ave', 'address2'...
# 4  {'address1': '1490 University Ave', 'address2'...
#
#                                          coordinates  avg_rating  \
# 0  {'latitude': 33.955971, 'longitude': -117.330408}         4.5
# 1  {'latitude': 33.955971, 'longitude': -117.330408}         4.5
# 2  {'latitude': 33.955971, 'longitude': -117.330408}         4.5
# 3    {'latitude': 33.97533, 'longitude': -117.34385}         4.3
# 4    {'latitude': 33.97533, 'longitude': -117.34385}         4.3
#
#                 review_id                                               user  \
# 0  e84DJb5bqU63D-7cObU4pQ  {'id': 'KcxN-hBjh7OsdQJh_0xvWA', 'profile_url'...
# 1  rWQ-KpfjLDTBes6LarDuhg  {'id': 'DJDC7kwj4qItmsi5BXWC8A', 'profile_url'...
# 2  O3Rnl2Ew8uulDA_TBPTDtA  {'id': 'S3gYxVAwJcGy76e3gdJZBg', 'profile_url'...
# 3  UV3u1IbW-q38XWgTZgRdnQ  {'id': 'kQKosEedp_QFSZS7wyB3Og', 'profile_url'...
# 4  43QScRvU-r0NLjt-dzG5WQ  {'id': 'ORK17DiBQHAmLYdEjzsnJQ', 'profile_url'...
#
#    review_rating                                        review_text  \
# 0              4  Food was good, service was great, Alexa was ve...
# 1              5  Absolutely love the atmosphere and the food is...
# 2              3  They ran out of fries and coleslaw and still c...
# 3              5  Excellent + food was delicious, great portion,...
# 4              5  The food was amazing! We had the gyro's and hu...
#
#            review_date
# 0  2025-04-05 12:27:18
# 1  2025-03-23 21:16:35
# 2  2025-03-03 03:39:00
# 3  2025-04-06 11:01:58
# 4  2024-11-08 15:17:32

# %%
#all_restaurants_data = search_all_restaurants(latitude, longitude, radius, "restaurants")

if all_restaurants_data:
    restaurants_df = pd.DataFrame(all_restaurants_data)
    print(f"\nSuccessfully fetched a total of {len(restaurants_df)} restaurants.")
    print("\nFirst 5 rows of the restaurants DataFrame (initial):")
    print(restaurants_df.head())

    # Add a column to store the description
    restaurants_df['description'] = None

    print("\nFetching business details (including description) for each restaurant...")
    for index, row in restaurants_df.iterrows():
        business_id = row['id']
        business_details_endpoint = f"{YELP_API_BASE_URL}/businesses/{business_id}"
        try:
            response = requests.get(business_details_endpoint, headers=headers)
            response.raise_for_status()
            business_details = response.json()
            print(f"\nFull Business Details Response for {business_id}:")
            print(json.dumps(business_details, indent=4)) # Print the full JSON with indentation

            if 'snippet' in business_details:
                restaurants_df.loc[index, 'description'] = business_details['snippet']
            elif 'name' in business_details: # Fallback to name if no snippet
                restaurants_df.loc[index, 'description'] = f"Description not available. Showing name: {business_details['name']}"
            else:
                restaurants_df.loc[index, 'description'] = "Description not available."
            print(f"Description: {restaurants_df.loc[index, 'description']}")

            # Be mindful of API call limits

        except requests.exceptions.RequestException as e:
            print(f"Error fetching details for business ID {business_id}: {e}")
            restaurants_df.loc[index, 'description'] = "Error fetching description."

    print("\nFirst 5 rows of the restaurants DataFrame (with description):")
    print(restaurants_df[['id', 'name', 'description']].head())

else:
    restaurants_df = pd.DataFrame()
    print("\nNo restaurants fetched.")
# Out:
# Successfully fetched a total of 200 restaurants.
#
# First 5 rows of the restaurants DataFrame (initial):
#                        id                                      alias  \
# 0  7XJsjflQAnQTzvQYzAwydA   smoke-and-fire-social-eatery-riverside-2
# 1  CG0qu39ItRcAd8J5liITYQ                       elias-pita-riverside
# 2  ElH8ZbPSG1rIFA3wXyFn5Q                   the-salted-pig-riverside
# 3  KIVSXV1MrwIUO8E02M0H6Q                craving-crab-haus-riverside
# 4  wsgdv_edV5bvssYk9pyOIg  georgie-s-mediterranean-cuisine-riverside
#
#                               name  \
# 0       Smoke & Fire Social Eatery
# 1                       Elias Pita
# 2                   The Salted Pig
# 3                Craving Crab Haus
# 4  Georgie’s Mediterranean Cuisine
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/_n6TU4...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/G65RHz...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/blk-Vh...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/3WhUY5...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/smoke-and-fire-social...          2672
# 1  https://www.yelp.com/biz/elias-pita-riverside?...          1160
# 2  https://www.yelp.com/biz/the-salted-pig-rivers...          3349
# 3  https://www.yelp.com/biz/craving-crab-haus-riv...           427
# 4  https://www.yelp.com/biz/georgie-s-mediterrane...           426
#
#                                           categories  rating  \
# 0  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 1  [{'alias': 'mediterranean', 'title': 'Mediterr...     4.3
# 2  [{'alias': 'gastropubs', 'title': 'Gastropubs'...     3.8
# 3  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 4  [{'alias': 'mediterranean', 'title': 'Mediterr...     4.5
#
#                                          coordinates  \
# 0  {'latitude': 33.955971, 'longitude': -117.330408}
# 1    {'latitude': 33.97533, 'longitude': -117.34385}
# 2    {'latitude': 33.98226, 'longitude': -117.37386}
# 3    {'latitude': 33.97674, 'longitude': -117.33752}
# 4  {'latitude': 33.95623720813322, 'longitude': -...
#
#                transactions price  \
# 0                        []    $$
# 1        [delivery, pickup]    $$
# 2                [delivery]    $$
# 3  [restaurant_reservation]    $$
# 4        [delivery, pickup]    $$
#
#                                             location         phone  \
# 0  {'address1': '5225 Canyon Crest Dr', 'address2...  +19517427309
# 1  {'address1': '1490 University Ave', 'address2'...  +19516866800
# 2  {'address1': '3750 Main St', 'address2': 'Ste ...  +19517425664
# 3  {'address1': '1201 University Ave', 'address2'...  +19517425859
# 4  {'address1': '5225 Canyon Crest Dr', 'address2...  +19518230440
#
#     display_phone     distance  \
# 0  (951) 742-7309  2642.903707
# 1  (951) 686-6800  1509.822879
# 2  (951) 742-5664  4243.221458
# 3  (951) 742-5859   904.674919
# 4  (951) 823-0440  2547.020308
#
#                                       business_hours  \
# 0  [{'open': [{'is_overnight': False, 'start': '1...
# 1  [{'open': [{'is_overnight': False, 'start': '1...
# 2  [{'open': [{'is_overnight': False, 'start': '1...
# 3  [{'open': [{'is_overnight': False, 'start': '1...
# 4  [{'open': [{'is_overnight': False, 'start': '1...
#
#                                           attributes
# 0  {'business_accepts_android_pay': True, 'busine...
# 1  {'business_accepts_android_pay': True, 'busine...
# 2  {'business_accepts_android_pay': True, 'busine...
# 3  {'has_pool_table': False, 'business_url': 'htt...
# 4  {'business_url': 'https://georgiesmediterranea...
#
# Fetching business details (including description) for each restaurant...
#
# Full Business Details Response for 7XJsjflQAnQTzvQYzAwydA:
# {
#     "id": "7XJsjflQAnQTzvQYzAwydA",
#     "alias": "smoke-and-fire-social-eatery-riverside-2",
#     "name": "Smoke & Fire Social Eatery",
#     "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj4G_U2mlY1VRyJJtg/o.jpg",
#     "is_claimed": true,
#     "is_closed": false,
#     "url": "https://www.yelp.com/biz/smoke-and-fire-social-eatery-riverside-2?adjust_creative=s2u-5RnsfwMJeHOvze7LIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=s2u-5RnsfwMJeHOvze7LIQ",
#     "phone": "+19517427309",
#     "display_phone": "(951) 742-7309",
#     "review_count": 2672,
#     "categories": [
#         {
#             "alias": "bbq",
#             "title": "Barbeque"
#         },
#         {
#             "alias": "tradamerican",
#             "title": "American"
#         },
#         {
#             "alias": "comfortfood",
#             "title": "Comfort Food"
#         }
#     ],
#     "rating": 4.5,
#     "location": {
#         "address1": "5225 Canyon Crest Dr",
#         "address2": "Unit 9",
#         "address3": "",
#         "city": "Riverside",
#         "zip_code": "92507",
#         "country": "US",
#         "state": "CA",
#         "display_address": [
#             "5225 Canyon Crest Dr",
#             "Unit 9",
#             "Riverside, CA 92507"
#         ],
#         "cross_streets": ""
#     },
#     "coordinates": {
#         "latitude": 33.955971,
#         "longitude": -117.330408
#     },
#     "photos": [
#         "https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj4G_U2mlY1VRyJJtg/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/FdquvznbLNUzVFDBV0Mt4A/o.jpg",
#         "https://s3-media4.fl.yelpcdn.com/bphoto/_nrdWaZw7Oeph86lL_q-sw/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/O2gSsWTjVEIN50OYlqn1Mw/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/b4UrEmpP4EHq-cJYD9NQHw/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/xIeZdk5a-kT2TVgTwOVHog/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/GnsEWyxhigpXIAOE6AByBw/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/MhQ7I5JyziCTsxLo3hTl4w/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/In7gIsMijB6bN4jfhcjV1w/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/1vkxTAIJnrG8UmYH61kzLQ/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/UPIkzuCdYFg2_3JN0iWXUA/o.jpg",
#         "https://s3-media4.fl.yelpcdn.com/bphoto/xsVK3N8GZSyC-7NvDNianA/o.jpg"
#     ],
#     "photo_details": [
#         {
#             "photo_id": "vGyDDj4G_U2mlY1VRyJJtg",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj4G_U2mlY1VRyJJtg/o.jpg",
#             "caption": "Flowers on table",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "7TQigXVsCSRhYCGl97FRBg",
#             "label": "food"
#         },
#         {
#             "photo_id": "FdquvznbLNUzVFDBV0Mt4A",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/FdquvznbLNUzVFDBV0Mt4A/o.jpg",
#             "caption": "Inside Dining area",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "1nchUSduaVppANMjUQHufA",
#             "label": "interior"
#         },
#         {
#             "photo_id": "_nrdWaZw7Oeph86lL_q-sw",
#             "url": "https://s3-media4.fl.yelpcdn.com/bphoto/_nrdWaZw7Oeph86lL_q-sw/o.jpg",
#             "caption": "Brisket fries",
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "UuI3UdEbKxWZw31ny3yzcQ",
#             "label": "food"
#         },
#         {
#             "photo_id": "O2gSsWTjVEIN50OYlqn1Mw",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/O2gSsWTjVEIN50OYlqn1Mw/o.jpg",
#             "caption": "Mural and dining area",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "WFBjwDXsInhZzuF5sU3Y3g",
#             "label": "interior"
#         },
#         {
#             "photo_id": "b4UrEmpP4EHq-cJYD9NQHw",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/b4UrEmpP4EHq-cJYD9NQHw/o.jpg",
#             "caption": "Corn bread",
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "O6HjMGAiWX2zIr2McjfQ4A",
#             "label": "food"
#         },
#         {
#             "photo_id": "xIeZdk5a-kT2TVgTwOVHog",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/xIeZdk5a-kT2TVgTwOVHog/o.jpg",
#             "caption": "View from table",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "T_xNKX-7lR6MzwIi0GoHzg",
#             "label": "interior"
#         },
#         {
#             "photo_id": "GnsEWyxhigpXIAOE6AByBw",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/GnsEWyxhigpXIAOE6AByBw/o.jpg",
#             "caption": "Dino Short Rib",
#             "width": 1564,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "rxi66uVFxghqaO6qu3DWDA",
#             "label": null
#         },
#         {
#             "photo_id": "MhQ7I5JyziCTsxLo3hTl4w",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/MhQ7I5JyziCTsxLo3hTl4w/o.jpg",
#             "caption": "Interior design",
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "dKclO8moSMD9pnHVpbShQg",
#             "label": "interior"
#         },
#         {
#             "photo_id": "In7gIsMijB6bN4jfhcjV1w",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/In7gIsMijB6bN4jfhcjV1w/o.jpg",
#             "caption": "Brisket Fries",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "wnPKc3FyU1doqa2zesmEEQ",
#             "label": "food"
#         },
#         {
#             "photo_id": "1vkxTAIJnrG8UmYH61kzLQ",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/1vkxTAIJnrG8UmYH61kzLQ/o.jpg",
#             "caption": "Dining area",
#             "width": 4500,
#             "height": 6000,
#             "is_user_submitted": true,
#             "user_id": "UGtUCLo-ryeefSzxZJvFlw",
#             "label": "interior"
#         },
#         {
#             "photo_id": "UPIkzuCdYFg2_3JN0iWXUA",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/UPIkzuCdYFg2_3JN0iWXUA/o.jpg",
#             "caption": "Smoked Cookies and Cream Dessert (over brownie)",
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "Mf_-HfdZbCUxO7-ObpiZaQ",
#             "label": "food"
#         },
#         {
#             "photo_id": "xsVK3N8GZSyC-7NvDNianA",
#             "url": "https://s3-media4.fl.yelpcdn.com/bphoto/xsVK3N8GZSyC-7NvDNianA/o.jpg",
#             "caption": "Brisket Quesadilla",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "P7oRsRGHnr9P9lLsUNoxwA",
#             "label": "food"
#         }
#     ],
#     "photo_count": 5602,
#     "price": "$$",
#     "hours": [
#         {
#             "open": [
#                 {
#                     "is_overnight": false,
#                     "start": "1000",
#                     "end": "2200",
#                     "day": 0
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1000",
#                     "end": "2200",
#                     "day": 1
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1000",
#                     "end": "2200",
#                     "day": 2
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1000",
#                     "end": "2200",
#                     "day": 3
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1000",
#                     "end": "2200",
#                     "day": 4
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1000",
#                     "end": "2200",
#                     "day": 5
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1000",
#                     "end": "2200",
#                     "day": 6
#                 }
#             ],
#             "hours_type": "REGULAR",
#             "is_open_now": true
#         }
#     ],
#     "attributes": {
#         "business_accepts_android_pay": true,
#         "business_accepts_apple_pay": true,
#         "business_url": "http://www.thesmokeandfire.com",
#         "about_this_biz_business_recommendation": [],
#         "about_this_biz_specialties": "Join us for our new Wing Menu rollout! Come try the 3 hottest flavors you can find. We're also now serving Brunch Thursday - Sunday 10am - 1pm.",
#         "alcohol": "beer_and_wine",
#         "ambience": {
#             "divey": false,
#             "hipster": null,
#             "casual": true,
#             "touristy": null,
#             "trendy": true,
#             "intimate": false,
#             "romantic": false,
#             "classy": null,
#             "upscale": null
#         },
#         "bike_parking": true,
#         "business_accepts_credit_cards": true,
#         "business_parking": {
#             "valet": false,
#             "garage": false,
#             "street": false,
#             "lot": true,
#             "validated": false
#         },
#         "caters": true,
#         "dogs_allowed": true,
#         "drive_thru": false,
#         "good_for_kids": true,
#         "good_for_meal": {
#             "breakfast": null,
#             "brunch": true,
#             "lunch": true,
#             "dinner": true,
#             "latenight": null,
#             "dessert": true
#         },
#         "happy_hour": true,
#         "has_tv": true,
#         "menu_url": "https://www.thesmokeandfire.com/menu",
#         "noise_level": "average",
#         "restaurants_delivery": true,
#         "restaurants_good_for_groups": true,
#         "restaurants_reservations": false,
#         "restaurants_table_service": false,
#         "restaurants_take_out": true,
#         "wi_fi": "no",
#         "outdoor_seating": true,
#         "liked_by_vegans": true
#     },
#     "transactions": [],
#     "messaging": {
#         "url": "https://www.yelp.com/raq/7XJsjflQAnQTzvQYzAwydA?adjust_creative=s2u-5RnsfwMJeHOvze7LIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=s2u-5RnsfwMJeHOvze7LIQ#popup%3Araq",
#         "use_case_text": "Message the Business",
#         "response_rate": 0.0,
#         "response_time": null
#     }
# }
# Description: Description not available. Showing name: Smoke & Fire Social Eatery
#
# Full Business Details Response for CG0qu39ItRcAd8J5liITYQ:
# {
#     "id": "CG0qu39ItRcAd8J5liITYQ",
#     "alias": "elias-pita-riverside",
#     "name": "Elias Pita",
#     "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/_n6TU4YcMjiy8JEhqLkWxw/o.jpg",
#     "is_claimed": true,
#     "is_closed": false,
#     "url": "https://www.yelp.com/biz/elias-pita-riverside?adjust_creative=s2u-5RnsfwMJeHOvze7LIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=s2u-5RnsfwMJeHOvze7LIQ",
#     "phone": "+19516866800",
#     "display_phone": "(951) 686-6800",
#     "review_count": 1160,
#     "categories": [
#         {
#             "alias": "mediterranean",
#             "title": "Mediterranean"
#         },
#         {
#             "alias": "mideastern",
#             "title": "Middle Eastern"
#         },
#         {
#             "alias": "halal",
#             "title": "Halal"
#         }
#     ],
#     "rating": 4.3,
#     "location": {
#         "address1": "1490 University Ave",
#         "address2": "Ste 103",
#         "address3": "",
#         "city": "Riverside",
#         "zip_code": "92507",
#         "country": "US",
#         "state": "CA",
#         "display_address": [
#             "1490 University Ave",
#             "Ste 103",
#             "Riverside, CA 92507"
#         ],
#         "cross_streets": ""
#     },
#     "coordinates": {
#         "latitude": 33.97533,
#         "longitude": -117.34385
#     },
#     "photos": [
#         "https://s3-media2.fl.yelpcdn.com/bphoto/_n6TU4YcMjiy8JEhqLkWxw/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/PnrdA1Tj26eydwNfJrYHFQ/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/H1qF3r-BxnNRWh-VttnIGQ/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/bcLCIXb1TIEJrT-uiGq6oA/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/VzIXrrk4ZcZrmGyaK3Q19w/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/1LEM2y3-RUHP720Mv3XNsQ/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/XTp1u2--UXXeMtazuvXacw/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/X8nr8LEqYh7ew-tlDy0YKw/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/pRM2Bq-i7t-CBiTc3haLcA/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/5W7kPYJX0V2m8-uS_3rCgQ/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/vsTw3Uy9C0bISgl2dhTzDg/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/dOArGxhbO4f5HbSlw-KYyA/o.jpg"
#     ],
#     "photo_details": [
#         {
#             "photo_id": "_n6TU4YcMjiy8JEhqLkWxw",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/_n6TU4YcMjiy8JEhqLkWxw/o.jpg",
#             "caption": "Gyro $9.99",
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "11aM2nkWZxGcUhoK9mGXdw",
#             "label": "food"
#         },
#         {
#             "photo_id": "PnrdA1Tj26eydwNfJrYHFQ",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/PnrdA1Tj26eydwNfJrYHFQ/o.jpg",
#             "caption": "Inside  IG: FeedYo_Self",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "jrL8Y9bNpWsyVFVSMGOT0w",
#             "label": "interior"
#         },
#         {
#             "photo_id": "H1qF3r-BxnNRWh-VttnIGQ",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/H1qF3r-BxnNRWh-VttnIGQ/o.jpg",
#             "caption": "The best Homemade Baklava you will ever try",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "134UkYvG_HoYn0-D_pdvcw",
#             "label": "food"
#         },
#         {
#             "photo_id": "bcLCIXb1TIEJrT-uiGq6oA",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/bcLCIXb1TIEJrT-uiGq6oA/o.jpg",
#             "caption": "Outside  IG: FeedYo_Self",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "jrL8Y9bNpWsyVFVSMGOT0w",
#             "label": "outside"
#         },
#         {
#             "photo_id": "VzIXrrk4ZcZrmGyaK3Q19w",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/VzIXrrk4ZcZrmGyaK3Q19w/o.jpg",
#             "caption": "Delicious. That's the review.",
#             "width": 1505,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "hfmqAedSloNxIida8QeCJg",
#             "label": "food"
#         },
#         {
#             "photo_id": "1LEM2y3-RUHP720Mv3XNsQ",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/1LEM2y3-RUHP720Mv3XNsQ/o.jpg",
#             "caption": null,
#             "width": 2000,
#             "height": 946,
#             "is_user_submitted": true,
#             "user_id": "X3AXexEUVSqSXkmSBfXsFg",
#             "label": "food"
#         },
#         {
#             "photo_id": "XTp1u2--UXXeMtazuvXacw",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/XTp1u2--UXXeMtazuvXacw/o.jpg",
#             "caption": null,
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "ELdbjD21VkFjJqWEdMy7CQ",
#             "label": "food"
#         },
#         {
#             "photo_id": "X8nr8LEqYh7ew-tlDy0YKw",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/X8nr8LEqYh7ew-tlDy0YKw/o.jpg",
#             "caption": "Chicken Protein Salad!",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "z3mLmggFwri5TYUKVHstDQ",
#             "label": "food"
#         },
#         {
#             "photo_id": "pRM2Bq-i7t-CBiTc3haLcA",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/pRM2Bq-i7t-CBiTc3haLcA/o.jpg",
#             "caption": "Menu  IG: FeedYo_Self",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "jrL8Y9bNpWsyVFVSMGOT0w",
#             "label": "menu"
#         },
#         {
#             "photo_id": "5W7kPYJX0V2m8-uS_3rCgQ",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/5W7kPYJX0V2m8-uS_3rCgQ/o.jpg",
#             "caption": "Combination Plate",
#             "width": 2000,
#             "height": 1125,
#             "is_user_submitted": true,
#             "user_id": "8ISnl41CCPx_HimENhVnBg",
#             "label": "food"
#         },
#         {
#             "photo_id": "vsTw3Uy9C0bISgl2dhTzDg",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/vsTw3Uy9C0bISgl2dhTzDg/o.jpg",
#             "caption": "Chicken Kabab Plate",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "3-Wk1icQeVbC5497ndCBcw",
#             "label": "food"
#         },
#         {
#             "photo_id": "dOArGxhbO4f5HbSlw-KYyA",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/dOArGxhbO4f5HbSlw-KYyA/o.jpg",
#             "caption": "Menu  IG: FeedYo_Self",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "jrL8Y9bNpWsyVFVSMGOT0w",
#             "label": "interior"
#         }
#     ],
#     "photo_count": 716,
#     "price": "$$",
#     "hours": [
#         {
#             "open": [
#                 {
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "2100",
#                     "day": 0
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "2100",
#                     "day": 1
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "2100",
#                     "day": 2
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "2100",
#                     "day": 3
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "2100",
#                     "day": 4
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1200",
#                     "end": "2000",
#                     "day": 5
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1200",
#                     "end": "2000",
#                     "day": 6
#                 }
#             ],
#             "hours_type": "REGULAR",
#             "is_open_now": true
#         }
#     ],
#     "attributes": {
#         "business_accepts_android_pay": true,
#         "business_accepts_apple_pay": true,
#         "business_url": "http://www.eliaspita.com",
#         "about_this_biz_business_recommendation": [],
#         "about_this_biz_bio": "Elias Pita Restaurant offers fresh daily prepared authentic middle eastern food.\nWe have the best hummus in town hands down.\ncome try our shawarma's or kababs and we promise that you won't be disappointed.",
#         "about_this_biz_bio_first_name": "Elias",
#         "about_this_biz_bio_last_name": "P",
#         "about_this_biz_role": "Business Owner",
#         "about_this_biz_specialties": "If you've got a craving for kabobs or falafels, drop by Elias Pita for the best Middle Eastern eats in the \nRiverside area.",
#         "alcohol": "none",
#         "ambience": {
#             "divey": false,
#             "hipster": false,
#             "casual": true,
#             "touristy": false,
#             "trendy": false,
#             "intimate": false,
#             "romantic": false,
#             "classy": false,
#             "upscale": false
#         },
#         "bike_parking": true,
#         "business_accepts_credit_cards": true,
#         "business_parking": {
#             "garage": false,
#             "street": true,
#             "validated": false,
#             "lot": true,
#             "valet": false
#         },
#         "caters": true,
#         "dogs_allowed": false,
#         "good_for_kids": true,
#         "good_for_meal": {
#             "dessert": null,
#             "latenight": false,
#             "lunch": true,
#             "dinner": true,
#             "brunch": null,
#             "breakfast": false
#         },
#         "happy_hour": false,
#         "has_tv": true,
#         "menu_url": "http://eliaspita.com/menu/3771149",
#         "noise_level": "average",
#         "restaurants_attire": "casual",
#         "restaurants_delivery": true,
#         "restaurants_good_for_groups": true,
#         "restaurants_reservations": false,
#         "restaurants_table_service": false,
#         "restaurants_take_out": true,
#         "wi_fi": "free",
#         "liked_by_vegans": true,
#         "outdoor_seating": true,
#         "liked_by_vegetarians": true
#     },
#     "transactions": [
#         "delivery",
#         "pickup"
#     ],
#     "messaging": {
#         "response_rate": null,
#         "response_time": null
#     },
#     "yelp_menu_url": "https://www.yelp.com/menu/elias-pita-riverside"
# }
# Description: Description not available. Showing name: Elias Pita
#
# Full Business Details Response for ElH8ZbPSG1rIFA3wXyFn5Q:
# {
#     "id": "ElH8ZbPSG1rIFA3wXyFn5Q",
#     "alias": "the-salted-pig-riverside",
#     "name": "The Salted Pig",
#     "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/G65RHz57tZrfnKO4exdpkw/o.jpg",
#     "is_claimed": true,
#     "is_closed": false,
#     "url": "https://www.yelp.com/biz/the-salted-pig-riverside?adjust_creative=s2u-5RnsfwMJeHOvze7LIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=s2u-5RnsfwMJeHOvze7LIQ",
#     "phone": "+19517425664",
#     "display_phone": "(951) 742-5664",
#     "review_count": 3349,
#     "categories": [
#         {
#             "alias": "gastropubs",
#             "title": "Gastropubs"
#         },
#         {
#             "alias": "newamerican",
#             "title": "New American"
#         },
#         {
#             "alias": "breakfast_brunch",
#             "title": "Breakfast & Brunch"
#         }
#     ],
#     "rating": 3.8,
#     "location": {
#         "address1": "3750 Main St",
#         "address2": "Ste 103",
#         "address3": "",
#         "city": "Riverside",
#         "zip_code": "92501",
#         "country": "US",
#         "state": "CA",
#         "display_address": [
#             "3750 Main St",
#             "Ste 103",
#             "Riverside, CA 92501"
#         ],
#         "cross_streets": ""
#     },
#     "coordinates": {
#         "latitude": 33.98226,
#         "longitude": -117.37386
#     },
#     "photos": [
#         "https://s3-media3.fl.yelpcdn.com/bphoto/G65RHz57tZrfnKO4exdpkw/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/y6B2gyiDDPsXV9KiHYLcmQ/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/urMOVw2Eq_ZPaaXNKPINYw/o.jpg",
#         "https://s3-media4.fl.yelpcdn.com/bphoto/ImU8q9w3qT4OpuOPQjQe3g/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/lCOYn-OC78kgh5aFY205bA/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/kpn5iC4Fdyicnz1b1t8e6A/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/PB1pyHJym6O9-30rDGaFWw/o.jpg",
#         "https://s3-media4.fl.yelpcdn.com/bphoto/mlp5mSD0ABkPalgWtt4cTw/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/VaVAMlAk_q_3eupyF0wfgw/o.jpg",
#         "https://s3-media4.fl.yelpcdn.com/bphoto/wrpu-LAe1MMlv-HfEdvhrw/o.jpg",
#         "https://s3-media4.fl.yelpcdn.com/bphoto/b0dGy9RaPA_5plSjaZUI5g/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/ajF55APa4Wrr0Rn7Q__NKA/o.jpg"
#     ],
#     "photo_details": [
#         {
#             "photo_id": "G65RHz57tZrfnKO4exdpkw",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/G65RHz57tZrfnKO4exdpkw/o.jpg",
#             "caption": "Hamburger",
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "ThCXqdUbru0dYVLtUwYnpg",
#             "label": "food"
#         },
#         {
#             "photo_id": "y6B2gyiDDPsXV9KiHYLcmQ",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/y6B2gyiDDPsXV9KiHYLcmQ/o.jpg",
#             "caption": "Pink ceilings!",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "g-ItNVIZiJlJ9TPrcCRFHw",
#             "label": "interior"
#         },
#         {
#             "photo_id": "urMOVw2Eq_ZPaaXNKPINYw",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/urMOVw2Eq_ZPaaXNKPINYw/o.jpg",
#             "caption": "Pulpo Zarandeado",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "BNuPibT74jf8Kp47bZb7DQ",
#             "label": "food"
#         },
#         {
#             "photo_id": "ImU8q9w3qT4OpuOPQjQe3g",
#             "url": "https://s3-media4.fl.yelpcdn.com/bphoto/ImU8q9w3qT4OpuOPQjQe3g/o.jpg",
#             "caption": "Smash Burger",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "v_oGWE-TUYw-CtGO6uHlxw",
#             "label": "food"
#         },
#         {
#             "photo_id": "lCOYn-OC78kgh5aFY205bA",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/lCOYn-OC78kgh5aFY205bA/o.jpg",
#             "caption": "Bone Marrow",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "BNuPibT74jf8Kp47bZb7DQ",
#             "label": "food"
#         },
#         {
#             "photo_id": "kpn5iC4Fdyicnz1b1t8e6A",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/kpn5iC4Fdyicnz1b1t8e6A/o.jpg",
#             "caption": "Hamburger & salad",
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "ThCXqdUbru0dYVLtUwYnpg",
#             "label": "food"
#         },
#         {
#             "photo_id": "PB1pyHJym6O9-30rDGaFWw",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/PB1pyHJym6O9-30rDGaFWw/o.jpg",
#             "caption": "Tiki Night Drink",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "clvXW577cTCrBjaFKENb_w",
#             "label": null
#         },
#         {
#             "photo_id": "mlp5mSD0ABkPalgWtt4cTw",
#             "url": "https://s3-media4.fl.yelpcdn.com/bphoto/mlp5mSD0ABkPalgWtt4cTw/o.jpg",
#             "caption": "Falafel burger",
#             "width": 2000,
#             "height": 900,
#             "is_user_submitted": true,
#             "user_id": "KX-UXSAvpLUt1UwCywI_aQ",
#             "label": "food"
#         },
#         {
#             "photo_id": "VaVAMlAk_q_3eupyF0wfgw",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/VaVAMlAk_q_3eupyF0wfgw/o.jpg",
#             "caption": "Sammi Sandwich",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "g-ItNVIZiJlJ9TPrcCRFHw",
#             "label": "food"
#         },
#         {
#             "photo_id": "wrpu-LAe1MMlv-HfEdvhrw",
#             "url": "https://s3-media4.fl.yelpcdn.com/bphoto/wrpu-LAe1MMlv-HfEdvhrw/o.jpg",
#             "caption": "Mekong Maiden",
#             "width": 1352,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "v_oGWE-TUYw-CtGO6uHlxw",
#             "label": "drink"
#         },
#         {
#             "photo_id": "b0dGy9RaPA_5plSjaZUI5g",
#             "url": "https://s3-media4.fl.yelpcdn.com/bphoto/b0dGy9RaPA_5plSjaZUI5g/o.jpg",
#             "caption": "Lavender Blackberry Cheesecake",
#             "width": 1632,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "v_oGWE-TUYw-CtGO6uHlxw",
#             "label": "food"
#         },
#         {
#             "photo_id": "ajF55APa4Wrr0Rn7Q__NKA",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/ajF55APa4Wrr0Rn7Q__NKA/o.jpg",
#             "caption": "Dirty Fries",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "v_oGWE-TUYw-CtGO6uHlxw",
#             "label": "food"
#         }
#     ],
#     "photo_count": 3610,
#     "price": "$$",
#     "hours": [
#         {
#             "open": [
#                 {
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "2200",
#                     "day": 2
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "2200",
#                     "day": 3
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "2200",
#                     "day": 4
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1000",
#                     "end": "2200",
#                     "day": 5
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1000",
#                     "end": "2100",
#                     "day": 6
#                 }
#             ],
#             "hours_type": "REGULAR",
#             "is_open_now": true
#         }
#     ],
#     "attributes": {
#         "business_accepts_android_pay": true,
#         "business_accepts_apple_pay": true,
#         "business_url": "http://www.thesaltedpig.com",
#         "about_this_biz_business_recommendation": [],
#         "business_temp_closed": 1767254400,
#         "about_this_biz_bio": "Welcome to The Salted Pig",
#         "about_this_biz_bio_first_name": "Ronaldo",
#         "about_this_biz_bio_last_name": "F",
#         "about_this_biz_role": "Business Owner",
#         "about_this_biz_specialties": "Welcome to The Salted Pig. We are a casual gastropub located in downtown Riverside.  Here we have but one goal: to serve what we feel is the best local and sustainable food, unique craft beers, boutique wines and high-end spirits possible. We wanted to create a place where everyone would love to hang out, that didn't close early or require reservations a month in advance. Be sure to check out our 12 rotating craft beer taps, our oak grilled burgers, and daily specials.",
#         "about_this_biz_year_established": "2011",
#         "alcohol": "full_bar",
#         "ambience": {
#             "divey": false,
#             "hipster": null,
#             "casual": null,
#             "touristy": false,
#             "trendy": true,
#             "intimate": false,
#             "romantic": false,
#             "classy": false,
#             "upscale": false
#         },
#         "bike_parking": false,
#         "business_accepts_credit_cards": true,
#         "business_parking": {
#             "valet": false,
#             "garage": true,
#             "street": true,
#             "lot": true,
#             "validated": false
#         },
#         "caters": false,
#         "dogs_allowed": false,
#         "drive_thru": false,
#         "good_for_kids": true,
#         "good_for_meal": {
#             "dessert": null,
#             "latenight": null,
#             "lunch": null,
#             "dinner": true,
#             "brunch": false,
#             "breakfast": false
#         },
#         "happy_hour": false,
#         "has_tv": false,
#         "menu_url": "http://www.thesaltedpig.com/#menu-section",
#         "noise_level": "average",
#         "platform_delivery": true,
#         "restaurants_delivery": false,
#         "restaurants_good_for_groups": true,
#         "restaurants_reservations": false,
#         "restaurants_table_service": true,
#         "restaurants_take_out": true,
#         "wi_fi": "free",
#         "liked_by_vegans": true,
#         "outdoor_seating": false,
#         "liked_by_vegetarians": true
#     },
#     "transactions": [
#         "delivery"
#     ],
#     "messaging": {
#         "response_rate": null,
#         "response_time": null
#     }
# }
# Description: Description not available. Showing name: The Salted Pig
#
# Full Business Details Response for KIVSXV1MrwIUO8E02M0H6Q:
# {
#     "id": "KIVSXV1MrwIUO8E02M0H6Q",
#     "alias": "craving-crab-haus-riverside",
#     "name": "Craving Crab Haus",
#     "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/blk-VhtaZ_gtXOFwv0BPEg/o.jpg",
#     "is_claimed": true,
#     "is_closed": false,
#     "url": "https://www.yelp.com/biz/craving-crab-haus-riverside?adjust_creative=s2u-5RnsfwMJeHOvze7LIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=s2u-5RnsfwMJeHOvze7LIQ",
#     "phone": "+19517425859",
#     "display_phone": "(951) 742-5859",
#     "review_count": 427,
#     "categories": [
#         {
#             "alias": "cajun",
#             "title": "Cajun/Creole"
#         },
#         {
#             "alias": "sportsbars",
#             "title": "Sports Bars"
#         },
#         {
#             "alias": "seafood",
#             "title": "Seafood"
#         }
#     ],
#     "rating": 4.5,
#     "location": {
#         "address1": "1201 University Ave",
#         "address2": "Ste 117",
#         "address3": "",
#         "city": "Riverside",
#         "zip_code": "92507",
#         "country": "US",
#         "state": "CA",
#         "display_address": [
#             "1201 University Ave",
#             "Ste 117",
#             "Riverside, CA 92507"
#         ],
#         "cross_streets": ""
#     },
#     "coordinates": {
#         "latitude": 33.97674,
#         "longitude": -117.33752
#     },
#     "photos": [
#         "https://s3-media2.fl.yelpcdn.com/bphoto/blk-VhtaZ_gtXOFwv0BPEg/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/2wW9qxYP33g0vyPLxHeW9Q/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/KOmV0Lg862fZ8PzZQDC8Iw/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/dF39K5vuwtimIQXKKQYw_g/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/I5wsOa6C_Ysdt7pg1bVcVQ/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/rrYAy-8PpAC-iaNs9TzrIA/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/PxK7gpj1w-9D1k_LwcoyFw/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/x-FAcBCGIk8KTDIpTaW_9A/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/T4sbVre2zzvKrz8PaXkRLA/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/h6p3xf_tGUiluP81i_K6-g/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/SlOZ11eeX7sHAGhNgWIP0g/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/H8t4V05BsxNGMjOwmTtNIQ/o.jpg"
#     ],
#     "photo_details": [
#         {
#             "photo_id": "blk-VhtaZ_gtXOFwv0BPEg",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/blk-VhtaZ_gtXOFwv0BPEg/o.jpg",
#             "caption": null,
#             "width": 750,
#             "height": 1102,
#             "is_user_submitted": false,
#             "user_id": null,
#             "label": "food"
#         },
#         {
#             "photo_id": "2wW9qxYP33g0vyPLxHeW9Q",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/2wW9qxYP33g0vyPLxHeW9Q/o.jpg",
#             "caption": "Food in the Bag",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "ied-gZhrop1EMvGt9b-UjQ",
#             "label": "food"
#         },
#         {
#             "photo_id": "KOmV0Lg862fZ8PzZQDC8Iw",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/KOmV0Lg862fZ8PzZQDC8Iw/o.jpg",
#             "caption": "Jambalaya shrimp pasta",
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "WkVQDPSmIpqEeaC2JMQkkw",
#             "label": "food"
#         },
#         {
#             "photo_id": "dF39K5vuwtimIQXKKQYw_g",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/dF39K5vuwtimIQXKKQYw_g/o.jpg",
#             "caption": "Pasta Jambalaya With Mussels & Shrimp",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "Lo5b1qR3dNZ_cquolKkMxg",
#             "label": "food"
#         },
#         {
#             "photo_id": "I5wsOa6C_Ysdt7pg1bVcVQ",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/I5wsOa6C_Ysdt7pg1bVcVQ/o.jpg",
#             "caption": "Garlic noodles with shrimp",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "Mn8optU_CLR92NqqBp-acw",
#             "label": "food"
#         },
#         {
#             "photo_id": "rrYAy-8PpAC-iaNs9TzrIA",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/rrYAy-8PpAC-iaNs9TzrIA/o.jpg",
#             "caption": "Out Food in the Bag",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "ied-gZhrop1EMvGt9b-UjQ",
#             "label": "food"
#         },
#         {
#             "photo_id": "PxK7gpj1w-9D1k_LwcoyFw",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/PxK7gpj1w-9D1k_LwcoyFw/o.jpg",
#             "caption": null,
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "5w0rjsT3StoEbf6f7V56Kw",
#             "label": "food"
#         },
#         {
#             "photo_id": "x-FAcBCGIk8KTDIpTaW_9A",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/x-FAcBCGIk8KTDIpTaW_9A/o.jpg",
#             "caption": null,
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "5w0rjsT3StoEbf6f7V56Kw",
#             "label": "food"
#         },
#         {
#             "photo_id": "T4sbVre2zzvKrz8PaXkRLA",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/T4sbVre2zzvKrz8PaXkRLA/o.jpg",
#             "caption": null,
#             "width": 1996,
#             "height": 1320,
#             "is_user_submitted": true,
#             "user_id": "Xs4cPMmYI0oeuJDdncz0DQ",
#             "label": "food"
#         },
#         {
#             "photo_id": "h6p3xf_tGUiluP81i_K6-g",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/h6p3xf_tGUiluP81i_K6-g/o.jpg",
#             "caption": "Yummm",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "ied-gZhrop1EMvGt9b-UjQ",
#             "label": "food"
#         },
#         {
#             "photo_id": "SlOZ11eeX7sHAGhNgWIP0g",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/SlOZ11eeX7sHAGhNgWIP0g/o.jpg",
#             "caption": "All in",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "ar6aV0LgujTNoJdFJoF8xw",
#             "label": "food"
#         },
#         {
#             "photo_id": "H8t4V05BsxNGMjOwmTtNIQ",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/H8t4V05BsxNGMjOwmTtNIQ/o.jpg",
#             "caption": "Seafood boil whole shabang spicy",
#             "width": 1126,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "q_-VtgZChkcETIwgpFO4oQ",
#             "label": "food"
#         }
#     ],
#     "photo_count": 446,
#     "price": "$$",
#     "hours": [
#         {
#             "open": [
#                 {
#                     "is_overnight": false,
#                     "start": "1300",
#                     "end": "2200",
#                     "day": 0
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1300",
#                     "end": "2200",
#                     "day": 1
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1300",
#                     "end": "2200",
#                     "day": 2
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1300",
#                     "end": "2200",
#                     "day": 3
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1200",
#                     "end": "2300",
#                     "day": 4
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1200",
#                     "end": "2300",
#                     "day": 5
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1200",
#                     "end": "2200",
#                     "day": 6
#                 }
#             ],
#             "hours_type": "REGULAR",
#             "is_open_now": true
#         }
#     ],
#     "attributes": {
#         "has_pool_table": false,
#         "business_url": "http://www.cravincrabhaus.com",
#         "about_this_biz_business_recommendation": [],
#         "about_this_biz_history": "Our seafood restaurant serving beers on tap as well as Happy Hours Cocktails established in 2021.",
#         "about_this_biz_specialties": "Daily Specials Available Monday to Thursday. Happy Hours for all Draft Beer. Beer Bucket Available. Free Parking Validations for all customers.",
#         "about_this_biz_year_established": "2021",
#         "alcohol": "full_bar",
#         "ambience": {
#             "divey": false,
#             "hipster": null,
#             "casual": true,
#             "touristy": null,
#             "trendy": null,
#             "intimate": false,
#             "romantic": null,
#             "classy": null,
#             "upscale": false
#         },
#         "best_nights": {
#             "monday": false,
#             "tuesday": false,
#             "wednesday": false,
#             "thursday": false,
#             "friday": false,
#             "saturday": true,
#             "sunday": false
#         },
#         "bike_parking": true,
#         "business_accepts_credit_cards": true,
#         "business_parking": {
#             "valet": false,
#             "garage": false,
#             "street": false,
#             "lot": false,
#             "validated": true
#         },
#         "caters": true,
#         "dogs_allowed": true,
#         "drive_thru": false,
#         "good_for_kids": true,
#         "good_for_meal": {
#             "breakfast": null,
#             "brunch": null,
#             "lunch": null,
#             "dinner": true,
#             "latenight": null,
#             "dessert": null
#         },
#         "happy_hour": true,
#         "has_tv": true,
#         "menu_url": "https://cravincrabhaus.com/menu",
#         "noise_level": "average",
#         "platform_delivery": true,
#         "restaurants_delivery": false,
#         "restaurants_good_for_groups": true,
#         "restaurants_reservations": true,
#         "restaurants_table_service": true,
#         "restaurants_take_out": true,
#         "waitlist_reservation": true,
#         "wi_fi": "free",
#         "outdoor_seating": true
#     },
#     "transactions": [
#         "restaurant_reservation"
#     ],
#     "messaging": {
#         "url": "https://www.yelp.com/raq/KIVSXV1MrwIUO8E02M0H6Q?adjust_creative=s2u-5RnsfwMJeHOvze7LIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=s2u-5RnsfwMJeHOvze7LIQ#popup%3Araq",
#         "use_case_text": "Message the Business",
#         "response_rate": 1.0,
#         "response_time": 7482
#     }
# }
# Description: Description not available. Showing name: Craving Crab Haus
#
# Full Business Details Response for wsgdv_edV5bvssYk9pyOIg:
# {
#     "id": "wsgdv_edV5bvssYk9pyOIg",
#     "alias": "georgie-s-mediterranean-cuisine-riverside",
#     "name": "Georgie\u2019s Mediterranean Cuisine",
#     "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/3WhUY5XFdgPIsUeU5Iia7g/o.jpg",
#     "is_claimed": true,
#     "is_closed": false,
#     "url": "https://www.yelp.com/biz/georgie-s-mediterranean-cuisine-riverside?adjust_creative=s2u-5RnsfwMJeHOvze7LIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=s2u-5RnsfwMJeHOvze7LIQ",
#     "phone": "+19518230440",
#     "display_phone": "(951) 823-0440",
#     "review_count": 426,
#     "categories": [
#         {
#             "alias": "mediterranean",
#             "title": "Mediterranean"
#         },
#         {
#             "alias": "mideastern",
#             "title": "Middle Eastern"
#         }
#     ],
# ...
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "1400",
#                     "day": 1
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "1400",
#                     "day": 2
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "1400",
#                     "day": 3
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "1400",
#                     "day": 4
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1800",
#                     "end": "2200",
#                     "day": 4
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1100",
#                     "end": "1400",
#                     "day": 5
#                 }
#             ],
#             "hours_type": "REGULAR",
#             "is_open_now": false
#         }
#     ],
#     "attributes": {
#         "business_accepts_android_pay": true,
#         "business_accepts_apple_pay": true,
#         "business_url": "https://www.arcadecoffeeroasters.com/pages/backstreet",
#         "about_this_biz_business_recommendation": [],
#         "about_this_biz_bio": "Backstreet is a local Riverside staple, and we love the opportunity to preserve and build upon what the McKluskeys started in 1967. Our mission is to create share moments with the community as we continue to serve the sandwiches Backstreet is known and loved for. ",
#         "about_this_biz_bio_first_name": "Stevie",
#         "about_this_biz_bio_last_name": "H",
#         "about_this_biz_history": "Mom and Pop McCluskey came to Riverside from Los Angeles in the 50's. They loved to eat at the many Jewish Deli's in and around LA. When they relocated to the Inland Empire there was no great sandwich shops, so they started Backstreet for everyone to enjoy!",
#         "about_this_biz_role": "Business Owner",
#         "about_this_biz_specialties": "We cook and cut our meat in our on-site kitchen, daily. The bread is baked fresh in town and delivered, 5 days / week. All ingredients are locally purchased!\nWe are famous for deli style sandwiches, \nhot roast beef, pastrami and corned beef, as well as cold turkey, ham & tuna salad. Your sandwiches come with a choice of a side dish (baked beans, potato salad, coleslaw or chips.) The potato salad is grandma's recipe. We make the dessert here on site. Our fresh banana creme pie is a customer favorite. Available salads include spinach salad (craisins, pistachios, and shaved parmesan cheese with raspberry vinaigrette dressing) or Cesar salad, both available with meat, as an add-on. Don't forget to stop at the veggie cart, included with your meal!\n\n45 years of relaxing garden, patio dining sets us apart from any other dining establishment in Riverside! We do have indoor seating for approx. 60 and outdoors we can seat 120. Venue rental is available upon request.\n\nWe look forward to seeing you on your next visit!",
#         "about_this_biz_year_established": "1967",
#         "alcohol": "beer_and_wine",
#         "ambience": {
#             "divey": false,
#             "hipster": false,
#             "casual": true,
#             "touristy": false,
#             "trendy": null,
#             "intimate": null,
#             "romantic": null,
#             "classy": false,
#             "upscale": false
#         },
#         "bike_parking": true,
#         "business_accepts_credit_cards": true,
#         "business_parking": {
#             "garage": false,
#             "street": true,
#             "validated": false,
#             "lot": true,
#             "valet": false
#         },
#         "caters": true,
#         "dogs_allowed": true,
#         "drive_thru": false,
#         "good_for_kids": true,
#         "good_for_meal": {
#             "dessert": false,
#             "latenight": false,
#             "lunch": true,
#             "dinner": false,
#             "brunch": false,
#             "breakfast": false
#         },
#         "has_tv": false,
#         "noise_level": "average",
#         "restaurants_delivery": true,
#         "restaurants_good_for_groups": true,
#         "restaurants_reservations": false,
#         "restaurants_table_service": true,
#         "restaurants_take_out": true,
#         "wi_fi": "free",
#         "outdoor_seating": true,
#         "liked_by_vegans": true
#     },
#     "transactions": [
#         "delivery",
#         "pickup"
#     ],
#     "messaging": {
#         "response_rate": null,
#         "response_time": null
#     },
#     "yelp_menu_url": "https://www.yelp.com/menu/backstreet-riverside"
# }
# Description: Description not available. Showing name: Backstreet
#
# Full Business Details Response for kmdrAFVh0A82ZH8aFoZdAQ:
# {
#     "id": "kmdrAFVh0A82ZH8aFoZdAQ",
#     "alias": "my-hero-subs-riverside",
#     "name": "My Hero-Subs",
#     "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/VxvV8D0MsvtJNQ7qtzZrVg/o.jpg",
#     "is_claimed": true,
#     "is_closed": false,
#     "url": "https://www.yelp.com/biz/my-hero-subs-riverside?adjust_creative=s2u-5RnsfwMJeHOvze7LIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=s2u-5RnsfwMJeHOvze7LIQ",
#     "phone": "+19517847370",
#     "display_phone": "(951) 784-7370",
#     "review_count": 260,
#     "categories": [
#         {
#             "alias": "delis",
#             "title": "Delis"
#         },
#         {
#             "alias": "sandwiches",
#             "title": "Sandwiches"
#         },
#         {
#             "alias": "salad",
#             "title": "Salad"
#         }
#     ],
#     "rating": 4.1,
#     "location": {
#         "address1": "3355 Iowa Ave",
#         "address2": "",
#         "address3": "",
#         "city": "Riverside",
#         "zip_code": "92507",
#         "country": "US",
#         "state": "CA",
#         "display_address": [
#             "3355 Iowa Ave",
#             "Riverside, CA 92507"
#         ],
#         "cross_streets": ""
#     },
#     "coordinates": {
#         "latitude": 33.9819717407227,
#         "longitude": -117.34058380127
#     },
#     "photos": [
#         "https://s3-media4.fl.yelpcdn.com/bphoto/VxvV8D0MsvtJNQ7qtzZrVg/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/5CdRePmDwksUMA6oYJQsWQ/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/9yVwJgOlovsxzX7giX_zNg/o.jpg",
#         "https://s3-media4.fl.yelpcdn.com/bphoto/DJ4KOm2U--yo0tMl8badcg/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/cgSEnxsqgVWRGzHYJhqLig/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/9LIgiKKw0Iv8nR4OdhMcMg/o.jpg",
#         "https://s3-media2.fl.yelpcdn.com/bphoto/S47b07DBvp-bIGoOdYmSNg/o.jpg",
#         "https://s3-media4.fl.yelpcdn.com/bphoto/4BHPnzPUyCqrMdUkrZK6iQ/o.jpg",
#         "https://s3-media1.fl.yelpcdn.com/bphoto/KkyCmpG35OFYg64YAELT4w/o.jpg",
#         "https://s3-media4.fl.yelpcdn.com/bphoto/uOmxWxd_VlP1_wg57EfSuw/o.jpg",
#         "https://s3-media4.fl.yelpcdn.com/bphoto/JZETy4BhYXqvNg5so6xTQQ/o.jpg",
#         "https://s3-media3.fl.yelpcdn.com/bphoto/xyoEANZVfO7kiBZSF2mR1A/o.jpg"
#     ],
#     "photo_details": [
#         {
#             "photo_id": "VxvV8D0MsvtJNQ7qtzZrVg",
#             "url": "https://s3-media4.fl.yelpcdn.com/bphoto/VxvV8D0MsvtJNQ7qtzZrVg/o.jpg",
#             "caption": "Jr. Pastrami",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "a7A7hOV1wiJ9zcgfLqfP-g",
#             "label": "food"
#         },
#         {
#             "photo_id": "5CdRePmDwksUMA6oYJQsWQ",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/5CdRePmDwksUMA6oYJQsWQ/o.jpg",
#             "caption": "Kitchen",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "a7A7hOV1wiJ9zcgfLqfP-g",
#             "label": "interior"
#         },
#         {
#             "photo_id": "9yVwJgOlovsxzX7giX_zNg",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/9yVwJgOlovsxzX7giX_zNg/o.jpg",
#             "caption": "Chipotle Chicken sub  so goood!!! Added jalape\u00f1os in it",
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "bY5doXE-cX4NdYwHVktE0Q",
#             "label": "food"
#         },
#         {
#             "photo_id": "DJ4KOm2U--yo0tMl8badcg",
#             "url": "https://s3-media4.fl.yelpcdn.com/bphoto/DJ4KOm2U--yo0tMl8badcg/o.jpg",
#             "caption": "Menu(prices are now slightly higher).",
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "a7A7hOV1wiJ9zcgfLqfP-g",
#             "label": "menu"
#         },
#         {
#             "photo_id": "cgSEnxsqgVWRGzHYJhqLig",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/cgSEnxsqgVWRGzHYJhqLig/o.jpg",
#             "caption": "Happy hour all day 3.50$",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "OOl-ge0LMOHkShil_RtTzA",
#             "label": "drink"
#         },
#         {
#             "photo_id": "9LIgiKKw0Iv8nR4OdhMcMg",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/9LIgiKKw0Iv8nR4OdhMcMg/o.jpg",
#             "caption": "Menu(prices are now slightly higher). 04/26/2024",
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "a7A7hOV1wiJ9zcgfLqfP-g",
#             "label": "menu"
#         },
#         {
#             "photo_id": "S47b07DBvp-bIGoOdYmSNg",
#             "url": "https://s3-media2.fl.yelpcdn.com/bphoto/S47b07DBvp-bIGoOdYmSNg/o.jpg",
#             "caption": "Club Hero no tomatoes",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "U5tIoYGkKWuH3jk4-faykg",
#             "label": "food"
#         },
#         {
#             "photo_id": "4BHPnzPUyCqrMdUkrZK6iQ",
#             "url": "https://s3-media4.fl.yelpcdn.com/bphoto/4BHPnzPUyCqrMdUkrZK6iQ/o.jpg",
#             "caption": "I paid for avocado and they didn't put it, they charged me and the old bread",
#             "width": 3024,
#             "height": 4032,
#             "is_user_submitted": true,
#             "user_id": "DYidK8iXfBFbt-6r8oCCAw",
#             "label": "food"
#         },
#         {
#             "photo_id": "KkyCmpG35OFYg64YAELT4w",
#             "url": "https://s3-media1.fl.yelpcdn.com/bphoto/KkyCmpG35OFYg64YAELT4w/o.jpg",
#             "caption": null,
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "KqQpoKQhknGDTyGd0teu1w",
#             "label": "food"
#         },
#         {
#             "photo_id": "uOmxWxd_VlP1_wg57EfSuw",
#             "url": "https://s3-media4.fl.yelpcdn.com/bphoto/uOmxWxd_VlP1_wg57EfSuw/o.jpg",
#             "caption": "The updated menu 9/8/22",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "OOl-ge0LMOHkShil_RtTzA",
#             "label": "menu"
#         },
#         {
#             "photo_id": "JZETy4BhYXqvNg5so6xTQQ",
#             "url": "https://s3-media4.fl.yelpcdn.com/bphoto/JZETy4BhYXqvNg5so6xTQQ/o.jpg",
#             "caption": "Restaurant",
#             "width": 2000,
#             "height": 1500,
#             "is_user_submitted": true,
#             "user_id": "73DiBab3h85ciYC9gQmoEg",
#             "label": "interior"
#         },
#         {
#             "photo_id": "xyoEANZVfO7kiBZSF2mR1A",
#             "url": "https://s3-media3.fl.yelpcdn.com/bphoto/xyoEANZVfO7kiBZSF2mR1A/o.jpg",
#             "caption": "Pastrami Reuben Hero",
#             "width": 1500,
#             "height": 2000,
#             "is_user_submitted": true,
#             "user_id": "a7A7hOV1wiJ9zcgfLqfP-g",
#             "label": "food"
#         }
#     ],
#     "photo_count": 127,
#     "price": "$",
#     "hours": [
#         {
#             "open": [
#                 {
#                     "is_overnight": false,
#                     "start": "1030",
#                     "end": "1600",
#                     "day": 0
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1030",
#                     "end": "1600",
#                     "day": 1
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1030",
#                     "end": "1600",
#                     "day": 2
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1030",
#                     "end": "1800",
#                     "day": 3
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1030",
#                     "end": "1800",
#                     "day": 4
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1030",
#                     "end": "1600",
#                     "day": 5
#                 },
#                 {
#                     "is_overnight": false,
#                     "start": "1030",
#                     "end": "1600",
#                     "day": 6
#                 }
#             ],
#             "hours_type": "REGULAR",
#             "is_open_now": true
#         }
#     ],
#     "attributes": {
#         "business_accepts_apple_pay": false,
#         "about_this_biz_business_recommendation": [],
#         "alcohol": "beer_and_wine",
#         "ambience": {
#             "divey": false,
#             "hipster": false,
#             "casual": true,
#             "touristy": false,
#             "trendy": false,
#             "intimate": false,
#             "romantic": false,
#             "classy": true,
#             "upscale": false
#         },
#         "bike_parking": true,
#         "business_accepts_credit_cards": true,
#         "business_parking": {
#             "garage": false,
#             "street": false,
#             "validated": false,
#             "lot": true,
#             "valet": false
#         },
#         "caters": true,
#         "good_for_kids": true,
#         "good_for_meal": {
#             "dessert": false,
#             "latenight": false,
#             "lunch": true,
#             "dinner": false,
#             "brunch": false,
#             "breakfast": false
#         },
#         "has_tv": true,
#         "noise_level": "average",
#         "restaurants_delivery": true,
#         "restaurants_good_for_groups": true,
#         "restaurants_reservations": false,
#         "restaurants_table_service": false,
#         "restaurants_take_out": true,
#         "wi_fi": "no",
#         "liked_by_vegetarians": false,
#         "outdoor_seating": false
#     },
#     "transactions": [
#         "delivery",
#         "pickup"
#     ],
#     "messaging": {
#         "url": "https://www.yelp.com/raq/kmdrAFVh0A82ZH8aFoZdAQ?adjust_creative=s2u-5RnsfwMJeHOvze7LIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=s2u-5RnsfwMJeHOvze7LIQ#popup%3Araq",
#         "use_case_text": "Message the Business",
#         "response_rate": null,
#         "response_time": null
#     },
#     "yelp_menu_url": "https://www.yelp.com/menu/my-hero-subs-riverside"
# }
# Description: Description not available. Showing name: My Hero-Subs
#
# First 5 rows of the restaurants DataFrame (with description):
#                        id                             name  \
# 0  7XJsjflQAnQTzvQYzAwydA       Smoke & Fire Social Eatery
# 1  CG0qu39ItRcAd8J5liITYQ                       Elias Pita
# 2  ElH8ZbPSG1rIFA3wXyFn5Q                   The Salted Pig
# 3  KIVSXV1MrwIUO8E02M0H6Q                Craving Crab Haus
# 4  wsgdv_edV5bvssYk9pyOIg  Georgie’s Mediterranean Cuisine
#
#                                          description
# 0  Description not available. Showing name: Smoke...
# 1  Description not available. Showing name: Elias...
# 2  Description not available. Showing name: The S...
# 3  Description not available. Showing name: Cravi...
# 4  Description not available. Showing name: Georg...

# %%
restaurants_df.head(20)
# Out:
#                         id                                            alias  \
# 0   7XJsjflQAnQTzvQYzAwydA         smoke-and-fire-social-eatery-riverside-2
# 1   CG0qu39ItRcAd8J5liITYQ                             elias-pita-riverside
# 2   ElH8ZbPSG1rIFA3wXyFn5Q                         the-salted-pig-riverside
# 3   KIVSXV1MrwIUO8E02M0H6Q                      craving-crab-haus-riverside
# 4   wsgdv_edV5bvssYk9pyOIg        georgie-s-mediterranean-cuisine-riverside
# 5   sS_qTKCEmjpUnMiToaE5_A                 habanero-mexican-grill-riverside
# 6   XdEtxpf1k7KsqMf8FaJmXA                         kimchichanga-riverside-3
# 7   6gIcfFdEAz--Ugc2ctTK-w                       big-sky-bistro-riverside-3
# 8   apibcypiWTD4G8ZooNA8Cg                               palenque-riverside
# 9   CfKC29D6iTs1mYMk0f_KkQ           pepitos-mexican-restaurant-riverside-3
# 10  rUNoYQUU60Yq-bpCT0xUZQ                        the-sub-station-riverside
# 11  3xct6CRnvANgGUMrO4tcNw                           hk-bbq-house-riverside
# 12  7evtcHPkwNgsviQWsyOMbg                            sushi-times-riverside
# 13  AySNn4t4yfb_q0Ka6LqxZw       el-fogon-mexican-grill-riverside-riverside
# 14  O0N-JcIrQ-LAbjbT-1M5Sw  the-lobby-cocktail-lounge-and-kitchen-riverside
# 15  q3nAiu5Tz8Xcg--PptWu_Q                            sushi-r91-riverside-2
# 16  03u5O8Gu8kBBhvQIGCVQXA                        craftz-lounge-riverside-3
# 17  kLqXZ-XldTzv0uTIh92Wow                            el-patrón-riverside-4
# 18  kvlsxh6QndtgObsa6avU8w                      best-thai-cuisine-riverside
# 19  EupItiepZ3S9u5rduO_Xlw                           le-chat-noir-riverside
#
#                                     name  \
# 0             Smoke & Fire Social Eatery
# 1                             Elias Pita
# 2                         The Salted Pig
# 3                      Craving Crab Haus
# 4        Georgie’s Mediterranean Cuisine
# 5                 Habanero Mexican Grill
# 6                           Kimchichanga
# 7                         Big Sky Bistro
# 8                               Palenque
# 9             Pepitos Mexican restaurant
# 10                       The Sub Station
# 11                          HK BBQ House
# 12                           Sushi Times
# 13      El Fogon Mexican Grill Riverside
# 14  The Lobby Cocktail Lounge & Kitchen
# 15                             Sushi R91
# 16                         Craftz Lounge
# 17                             El Patrón
# 18                     Best Thai Cuisine
# 19                          Le Chat Noir
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/_n6TU4...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/G65RHz...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/blk-Vh...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/3WhUY5...      False
# 5   https://s3-media4.fl.yelpcdn.com/bphoto/a3PMiy...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/JqQyC3...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/sw88RJ...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/0QIupR...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/C3m3tA...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/vb3vcT...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/EDLXNQ...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/IBmK7K...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/-JYqqz...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/rQXOOk...      False
# 15  https://s3-media4.fl.yelpcdn.com/bphoto/AM-5Hb...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/iX5Jwl...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/MtFuqt...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/T0F--n...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/1qJTm-...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/smoke-and-fire-social...          2672
# 1   https://www.yelp.com/biz/elias-pita-riverside?...          1160
# 2   https://www.yelp.com/biz/the-salted-pig-rivers...          3349
# 3   https://www.yelp.com/biz/craving-crab-haus-riv...           427
# 4   https://www.yelp.com/biz/georgie-s-mediterrane...           426
# 5   https://www.yelp.com/biz/habanero-mexican-gril...          1075
# 6   https://www.yelp.com/biz/kimchichanga-riversid...          1141
# 7   https://www.yelp.com/biz/big-sky-bistro-rivers...           621
# 8   https://www.yelp.com/biz/palenque-riverside?ad...          1019
# 9   https://www.yelp.com/biz/pepitos-mexican-resta...           813
# 10  https://www.yelp.com/biz/the-sub-station-river...           410
# 11  https://www.yelp.com/biz/hk-bbq-house-riversid...           220
# 12  https://www.yelp.com/biz/sushi-times-riverside...           327
# 13  https://www.yelp.com/biz/el-fogon-mexican-gril...           559
# 14  https://www.yelp.com/biz/the-lobby-cocktail-lo...           736
# 15  https://www.yelp.com/biz/sushi-r91-riverside-2...           870
# 16  https://www.yelp.com/biz/craftz-lounge-riversi...           241
# 17  https://www.yelp.com/biz/el-patr%C3%B3n-rivers...           931
# 18  https://www.yelp.com/biz/best-thai-cuisine-riv...          1048
# 19  https://www.yelp.com/biz/le-chat-noir-riversid...           510
#
#                                            categories  rating  \
# 0   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 1   [{'alias': 'mediterranean', 'title': 'Mediterr...     4.3
# 2   [{'alias': 'gastropubs', 'title': 'Gastropubs'...     3.8
# 3   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 4   [{'alias': 'mediterranean', 'title': 'Mediterr...     4.5
# 5   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.6
# 6   [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.1
# 7   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.1
# 8   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.4
# 9          [{'alias': 'mexican', 'title': 'Mexican'}]     3.9
# 10   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     4.3
# 11  [{'alias': 'cantonese', 'title': 'Cantonese'},...     4.4
# 12  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 13         [{'alias': 'mexican', 'title': 'Mexican'}]     4.1
# 14  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.1
# 15  [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.7
# 16  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.3
# 17  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.0
# 18  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     3.9
# 19  [{'alias': 'french', 'title': 'French'}, {'ali...     4.6
#
#                                           coordinates  \
# 0   {'latitude': 33.955971, 'longitude': -117.330408}
# 1     {'latitude': 33.97533, 'longitude': -117.34385}
# 2     {'latitude': 33.98226, 'longitude': -117.37386}
# 3     {'latitude': 33.97674, 'longitude': -117.33752}
# 4   {'latitude': 33.95623720813322, 'longitude': -...
# 5   {'latitude': 33.9755435848719, 'longitude': -1...
# 6   {'latitude': 33.9760835, 'longitude': -117.338...
# 7   {'latitude': 33.9759522815083, 'longitude': -1...
# 8    {'latitude': 33.982619, 'longitude': -117.37445}
# 9   {'latitude': 33.9564945825428, 'longitude': -1...
# 10  {'latitude': 33.9772115054625, 'longitude': -1...
# 11     {'latitude': 33.97711, 'longitude': -117.3395}
# 12  {'latitude': 33.975371, 'longitude': -117.341793}
# 13  {'latitude': 33.983394, 'longitude': -117.327177}
# 14  {'latitude': 33.98249111181561, 'longitude': -...
# 15  {'latitude': 33.990055, 'longitude': -117.346889}
# 16     {'latitude': 33.98263, 'longitude': -117.3745}
# 17  {'latitude': 33.9799324, 'longitude': -117.368...
# 18  {'latitude': 33.990671, 'longitude': -117.349371}
# 19  {'latitude': 33.981309, 'longitude': -117.376295}
#
#                 transactions price  \
# 0                         []    $$
# 1         [delivery, pickup]    $$
# 2                 [delivery]    $$
# 3   [restaurant_reservation]    $$
# 4         [delivery, pickup]    $$
# 5                 [delivery]    $$
# 6         [delivery, pickup]    $$
# 7                   [pickup]    $$
# 8                         []    $$
# 9                 [delivery]    $$
# 10        [delivery, pickup]    $$
# 11                        []    $$
# 12        [delivery, pickup]    $$
# 13        [delivery, pickup]     $
# 14                        []    $$
# 15        [delivery, pickup]    $$
# 16  [restaurant_reservation]    $$
# 17                        []    $$
# 18                [delivery]    $$
# 19                [delivery]   $$$
#
#                                              location         phone  \
# 0   {'address1': '5225 Canyon Crest Dr', 'address2...  +19517427309
# 1   {'address1': '1490 University Ave', 'address2'...  +19516866800
# 2   {'address1': '3750 Main St', 'address2': 'Ste ...  +19517425664
# 3   {'address1': '1201 University Ave', 'address2'...  +19517425859
# 4   {'address1': '5225 Canyon Crest Dr', 'address2...  +19518230440
# 5   {'address1': '2472 University Ave', 'address2'...  +19512249145
# 6   {'address1': '1223 University Ave', 'address2'...  +19516849800
# 7   {'address1': '1575 University Ave', 'address2'...  +19513281688
# 8   {'address1': '3737 Main St', 'address2': None,...  +19518882240
# 9   {'address1': '5225 Canyon Crest Dr', 'address2...  +19517839444
# 10  {'address1': '3663 Canyon Crest Dr', 'address2...  +19516834523
# 11  {'address1': '3740 Iowa Ave', 'address2': 'Ste...  +19517771368
# 12  {'address1': '1400 University Ave', 'address2'...  +19517771037
# 13  {'address1': '765 W Blaine St', 'address2': ''...  +19517828959
# 14  {'address1': '3730 Main St', 'address2': '', '...  +19517425020
# 15  {'address1': '1630 Spruce St', 'address2': '',...  +19516821323
# 16  {'address1': '3720 Mission Inn Ave', 'address2...  +19517425670
# 17  {'address1': '3204 Mission Inn Ave', 'address2...  +19517771131
# 18  {'address1': '1735 Spruce St', 'address2': '',...  +19516824251
# 19  {'address1': '3790 9th St', 'address2': '', 'a...  +19517869266
#
#      display_phone     distance  \
# 0   (951) 742-7309  2642.903707
# 1   (951) 686-6800  1509.822879
# 2   (951) 742-5664  4243.221458
# 3   (951) 742-5859   904.674919
# 4   (951) 823-0440  2547.020308
# 5   (951) 224-9145  3088.029625
# 6   (951) 684-9800   983.066517
# 7   (951) 328-1688  1673.458963
# 8   (951) 888-2240  4289.092250
# 9   (951) 783-9444  2516.558119
# 10  (951) 683-4523   377.212421
# 11  (951) 777-1368  1071.309555
# 12  (951) 777-1037  1323.224105
# 13  (951) 782-8959   498.347921
# 14  (951) 742-5020  4238.388539
# 15  (951) 682-1323  2124.665128
# 16  (951) 742-5670  4282.774194
# 17  (951) 777-1131  3724.497264
# 18  (951) 682-4251  2352.050320
# 19  (951) 786-9266  4449.635802
#
#                                        business_hours  \
# 0   [{'open': [{'is_overnight': False, 'start': '1...
# 1   [{'open': [{'is_overnight': False, 'start': '1...
# 2   [{'open': [{'is_overnight': False, 'start': '1...
# 3   [{'open': [{'is_overnight': False, 'start': '1...
# 4   [{'open': [{'is_overnight': False, 'start': '1...
# 5   [{'open': [{'is_overnight': False, 'start': '1...
# 6   [{'open': [{'is_overnight': False, 'start': '1...
# 7   [{'open': [{'is_overnight': False, 'start': '1...
# 8   [{'open': [{'is_overnight': False, 'start': '1...
# 9   [{'open': [{'is_overnight': False, 'start': '1...
# 10  [{'open': [{'is_overnight': False, 'start': '0...
# 11  [{'open': [{'is_overnight': False, 'start': '1...
# 12  [{'open': [{'is_overnight': False, 'start': '1...
# 13  [{'open': [{'is_overnight': False, 'start': '1...
# 14  [{'open': [{'is_overnight': True, 'start': '16...
# 15  [{'open': [{'is_overnight': False, 'start': '1...
# 16  [{'open': [{'is_overnight': False, 'start': '1...
# 17  [{'open': [{'is_overnight': False, 'start': '0...
# 18  [{'open': [{'is_overnight': False, 'start': '1...
# 19  [{'open': [{'is_overnight': False, 'start': '1...
#
#                                            attributes  \
# 0   {'business_accepts_android_pay': True, 'busine...
# 1   {'business_accepts_android_pay': True, 'busine...
# 2   {'business_accepts_android_pay': True, 'busine...
# 3   {'has_pool_table': False, 'business_url': 'htt...
# 4   {'business_url': 'https://georgiesmediterranea...
# 5   {'business_accepts_android_pay': True, 'busine...
# 6   {'business_accepts_android_pay': True, 'busine...
# 7   {'business_accepts_apple_pay': True, 'business...
# 8   {'business_url': 'http://www.palenquekitchen.c...
# 9   {'business_url': 'https://www.pepitosfood.com'...
# 10  {'business_accepts_android_pay': False, 'busin...
# 11  {'business_accepts_android_pay': True, 'busine...
# 12  {'business_accepts_android_pay': True, 'busine...
# 13  {'business_accepts_android_pay': False, 'busin...
# 14  {'has_pool_table': False, 'business_url': 'htt...
# 15  {'business_accepts_android_pay': False, 'busin...
# 16  {'business_accepts_apple_pay': True, 'has_pool...
# 17  {'business_accepts_android_pay': True, 'busine...
# 18  {'business_accepts_android_pay': False, 'busin...
# 19  {'business_accepts_apple_pay': False, 'busines...
#
#                                           description
# 0   Description not available. Showing name: Smoke...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None

# %%
restaurant_reviews_final_df.head()
# Out:
#               business_id                        name  \
# 0  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 1  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 2  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 3  CG0qu39ItRcAd8J5liITYQ                  Elias Pita
# 4  CG0qu39ItRcAd8J5liITYQ                  Elias Pita
#
#                                           categories  \
# 0  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 1  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 2  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 3  [{'alias': 'mediterranean', 'title': 'Mediterr...
# 4  [{'alias': 'mediterranean', 'title': 'Mediterr...
#
#                                             location  \
# 0  {'address1': '5225 Canyon Crest Dr', 'address2...
# 1  {'address1': '5225 Canyon Crest Dr', 'address2...
# 2  {'address1': '5225 Canyon Crest Dr', 'address2...
# 3  {'address1': '1490 University Ave', 'address2'...
# 4  {'address1': '1490 University Ave', 'address2'...
#
#                                          coordinates  avg_rating  \
# 0  {'latitude': 33.955971, 'longitude': -117.330408}         4.5
# 1  {'latitude': 33.955971, 'longitude': -117.330408}         4.5
# 2  {'latitude': 33.955971, 'longitude': -117.330408}         4.5
# 3    {'latitude': 33.97533, 'longitude': -117.34385}         4.3
# 4    {'latitude': 33.97533, 'longitude': -117.34385}         4.3
#
#                 review_id                                               user  \
# 0  e84DJb5bqU63D-7cObU4pQ  {'id': 'KcxN-hBjh7OsdQJh_0xvWA', 'profile_url'...
# 1  rWQ-KpfjLDTBes6LarDuhg  {'id': 'DJDC7kwj4qItmsi5BXWC8A', 'profile_url'...
# 2  O3Rnl2Ew8uulDA_TBPTDtA  {'id': 'S3gYxVAwJcGy76e3gdJZBg', 'profile_url'...
# 3  UV3u1IbW-q38XWgTZgRdnQ  {'id': 'kQKosEedp_QFSZS7wyB3Og', 'profile_url'...
# 4  43QScRvU-r0NLjt-dzG5WQ  {'id': 'ORK17DiBQHAmLYdEjzsnJQ', 'profile_url'...
#
#    review_rating                                        review_text  \
# 0              4  Food was good, service was great, Alexa was ve...
# 1              5  Absolutely love the atmosphere and the food is...
# 2              3  They ran out of fries and coleslaw and still c...
# 3              5  Excellent + food was delicious, great portion,...
# 4              5  The food was amazing! We had the gyro's and hu...
#
#            review_date
# 0  2025-04-05 12:27:18
# 1  2025-03-23 21:16:35
# 2  2025-03-03 03:39:00
# 3  2025-04-06 11:01:58
# 4  2024-11-08 15:17:32

# %%
if not restaurant_reviews_df.empty:
    restaurant_reviews_final_df = pd.merge(restaurants_df[['id', 'description', 'attributes', 'transactions', 'distance', 'business_hours']], restaurant_reviews_df, left_on='id', right_on='business_id', how='inner')
    restaurant_reviews_final_df = restaurant_reviews_final_df[[
        'id_x',
        'name',
        'categories_x',
        'location',
        'coordinates',
        'rating_x',
        'review_id',
        'user',
        'rating_y',
        'text',
        'time_created',
        'description',
        'attributes',  # Include extracted attributes
        'transactions',          # Include transactions
        'distance',              # Include distance
        'business_hours'         # Include business_hours
    ]].copy()
    restaurant_reviews_final_df.rename(columns={
        'id_x': 'business_id',
        'categories_x': 'categories',
        'rating_x': 'avg_rating',
        'rating_y': 'review_rating',
        'text': 'review_text',
        'time_created': 'review_date',
        'description': 'description',
        'attributes': 'restaurant_details',
        'transactions': 'transactions',
        'distance': 'distance_from_riverside',  # Added a more descriptive name
        'business_hours': 'business_hours'
    }, inplace=True)
    print("\nFirst 5 rows of the final combined DataFrame (with restaurant details, transactions, distance, and business hours):")
    print(restaurant_reviews_final_df.head())
else:
    print("\nFinal combined DataFrame is empty.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 3
#       1 if not restaurant_reviews_df.empty:
#       2     restaurant_reviews_final_df = pd.merge(restaurants_df[['id', 'description', 'attributes', 'transactions', 'distance', 'business_hours']], restaurant_reviews_df, left_on='id', right_on='business_id', how='inner')
# ----> 3     restaurant_reviews_final_df = restaurant_reviews_final_df[[
#       4         'id_x',
#       5         'name',
#       6         'categories_x',
#       7         'location',
#       8         'coordinates',
#       9         'rating_x',
#      10         'review_id',
#      11         'user',
#      12         'rating_y',
#      13         'text',
#      14         'time_created',
#      15         'description',
#      16         'attributes',  # Include extracted attributes
#      17         'transactions',          # Include transactions
#      18         'distance',              # Include distance
#      19         'business_hours'         # Include business_hours
#      20     ]].copy()
#      21     restaurant_reviews_final_df.rename(columns={
#      22         'id_x': 'business_id',
#      23         'categories_x': 'categories',
#    (...)
#      32         'business_hours': 'business_hours'
#      33     }, inplace=True)
#      34     print("\nFirst 5 rows of the final combined DataFrame (with restaurant details, transactions, distance, and business hours):")
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['categories_x', 'review_id', 'attributes', 'transactions', 'distance', 'business_hours'] not in index"

# %%
restaurant_reviews_df = pd.merge(restaurants_df[['id', 'name', 'attributes', 'transactions', 'distance', 'business_hours']], reviews_df, left_on='id', right_on='business_id', how='inner')

# %%
restaurant_reviews_df
# Out:
#                        id_x  \
# 0    7XJsjflQAnQTzvQYzAwydA
# 1    7XJsjflQAnQTzvQYzAwydA
# 2    7XJsjflQAnQTzvQYzAwydA
# 3    CG0qu39ItRcAd8J5liITYQ
# 4    CG0qu39ItRcAd8J5liITYQ
# ..                      ...
# 595  bMKxq1N2jtl1fIz38GU4aA
# 596  bMKxq1N2jtl1fIz38GU4aA
# 597  kmdrAFVh0A82ZH8aFoZdAQ
# 598  kmdrAFVh0A82ZH8aFoZdAQ
# 599  kmdrAFVh0A82ZH8aFoZdAQ
#
#                                            description  \
# 0    Description not available. Showing name: Smoke...
# 1    Description not available. Showing name: Smoke...
# 2    Description not available. Showing name: Smoke...
# 3    Description not available. Showing name: Elias...
# 4    Description not available. Showing name: Elias...
# ..                                                 ...
# 595  Description not available. Showing name: Backs...
# 596  Description not available. Showing name: Backs...
# 597  Description not available. Showing name: My He...
# 598  Description not available. Showing name: My He...
# 599  Description not available. Showing name: My He...
#
#                                             attributes        transactions  \
# 0    {'business_accepts_android_pay': True, 'busine...                  []
# 1    {'business_accepts_android_pay': True, 'busine...                  []
# 2    {'business_accepts_android_pay': True, 'busine...                  []
# 3    {'business_accepts_android_pay': True, 'busine...  [delivery, pickup]
# 4    {'business_accepts_android_pay': True, 'busine...  [delivery, pickup]
# ..                                                 ...                 ...
# 595  {'business_accepts_android_pay': True, 'busine...  [delivery, pickup]
# 596  {'business_accepts_android_pay': True, 'busine...  [delivery, pickup]
# 597  {'business_accepts_apple_pay': False, 'busines...  [pickup, delivery]
# 598  {'business_accepts_apple_pay': False, 'busines...  [pickup, delivery]
# 599  {'business_accepts_apple_pay': False, 'busines...  [pickup, delivery]
#
#         distance                                     business_hours  \
# 0    2642.903707  [{'open': [{'is_overnight': False, 'start': '1...
# 1    2642.903707  [{'open': [{'is_overnight': False, 'start': '1...
# 2    2642.903707  [{'open': [{'is_overnight': False, 'start': '1...
# 3    1509.822879  [{'open': [{'is_overnight': False, 'start': '1...
# 4    1509.822879  [{'open': [{'is_overnight': False, 'start': '1...
# ..           ...                                                ...
# 595  7142.674700  [{'open': [{'is_overnight': False, 'start': '1...
# 596  7142.674700  [{'open': [{'is_overnight': False, 'start': '1...
# 597  1167.844957  [{'open': [{'is_overnight': False, 'start': '1...
# 598  1167.844957  [{'open': [{'is_overnight': False, 'start': '1...
# 599  1167.844957  [{'open': [{'is_overnight': False, 'start': '1...
#
#                        id_y  \
# 0    e84DJb5bqU63D-7cObU4pQ
# 1    rWQ-KpfjLDTBes6LarDuhg
# 2    O3Rnl2Ew8uulDA_TBPTDtA
# 3    UV3u1IbW-q38XWgTZgRdnQ
# 4    43QScRvU-r0NLjt-dzG5WQ
# ..                      ...
# 595  dkqAIXdtXXU4P17O5BhYjw
# 596  _JNOVcifNyjl_mmvxkHIhw
# 597  NmRpM5Pt5VjInz6Drd89mA
# 598  vzV9-t_O2EmBREmXVK9Tzw
# 599  uBoo7nxWdJSkZqXKW4fMlA
#
#                                                    url  \
# 0    https://www.yelp.com/biz/smoke-and-fire-social...
# 1    https://www.yelp.com/biz/smoke-and-fire-social...
# 2    https://www.yelp.com/biz/smoke-and-fire-social...
# 3    https://www.yelp.com/biz/elias-pita-riverside?...
# 4    https://www.yelp.com/biz/elias-pita-riverside?...
# ..                                                 ...
# 595  https://www.yelp.com/biz/backstreet-riverside?...
# 596  https://www.yelp.com/biz/backstreet-riverside?...
# 597  https://www.yelp.com/biz/my-hero-subs-riversid...
# 598  https://www.yelp.com/biz/my-hero-subs-riversid...
# 599  https://www.yelp.com/biz/my-hero-subs-riversid...
#
#                                                   text  rating  \
# 0    Food was good, service was great, Alexa was ve...       4
# 1    Absolutely love the atmosphere and the food is...       5
# 2    They ran out of fries and coleslaw and still c...       3
# 3    Excellent + food was delicious, great portion,...       5
# 4    The food was amazing! We had the gyro's and hu...       5
# ..                                                 ...     ...
# 595  I have been going to Backstreet for more than ...       5
# 596  Best sandwich shop in Riverside. A lil pricey ...       5
# 597  I always come here for sandwiches and I realiz...       5
# 598  Very popular small mom and pop submarine sandw...       4
# 599  I got the chipotle chicken, the amount of mayo...       1
#
#             time_created                                               user  \
# 0    2025-04-05 12:27:18  {'id': 'KcxN-hBjh7OsdQJh_0xvWA', 'profile_url'...
# 1    2025-03-23 21:16:35  {'id': 'DJDC7kwj4qItmsi5BXWC8A', 'profile_url'...
# 2    2025-03-03 03:39:00  {'id': 'S3gYxVAwJcGy76e3gdJZBg', 'profile_url'...
# 3    2025-04-06 11:01:58  {'id': 'kQKosEedp_QFSZS7wyB3Og', 'profile_url'...
# 4    2024-11-08 15:17:32  {'id': 'ORK17DiBQHAmLYdEjzsnJQ', 'profile_url'...
# ..                   ...                                                ...
# 595  2024-11-25 19:56:28  {'id': 'Dlv0LYWcx71cS0fZyRqqyA', 'profile_url'...
# 596  2024-11-25 14:24:03  {'id': 'Z9guTC__fTJ9-m-nji7Xqg', 'profile_url'...
# 597  2025-04-04 21:54:51  {'id': '0QmTpca-tbrYbgjWj2tYJw', 'profile_url'...
# 598  2025-03-21 12:33:51  {'id': 'fUrJ14NSDxGG0zHqAYjanw', 'profile_url'...
# 599  2025-03-06 12:16:34  {'id': 'NsI_b6j2_aSD3Bi_zZxiSA', 'profile_url'...
#
#                 business_id
# 0    7XJsjflQAnQTzvQYzAwydA
# 1    7XJsjflQAnQTzvQYzAwydA
# 2    7XJsjflQAnQTzvQYzAwydA
# 3    CG0qu39ItRcAd8J5liITYQ
# 4    CG0qu39ItRcAd8J5liITYQ
# ..                      ...
# 595  bMKxq1N2jtl1fIz38GU4aA
# 596  bMKxq1N2jtl1fIz38GU4aA
# 597  kmdrAFVh0A82ZH8aFoZdAQ
# 598  kmdrAFVh0A82ZH8aFoZdAQ
# 599  kmdrAFVh0A82ZH8aFoZdAQ
#
# [600 rows x 13 columns]

# %%
if not restaurants_df.empty and not reviews_df.empty:
    columns_to_merge = ['id', 'name', 'url', 'categories', 'rating', 'coordinates', 'price', 'location', 'phone', 'distance', 'business_hours']
    restaurants_df_subset = restaurants_df[columns_to_merge]
    restaurant_reviews_df = pd.merge(
        restaurants_df_subset,
        reviews_df,
        left_on='id',
        right_on='business_id',
        how='inner'
    )
    print(f"\nMerged DataFrame shape: {restaurant_reviews_df.shape}")
    print("\nFirst 5 rows of the merged DataFrame:")
    print(restaurant_reviews_df.head())
else:
    restaurant_reviews_df = pd.DataFrame()
    print("\nCould not merge restaurant and review data as one or both DataFrames are empty.")
# Out:
# Merged DataFrame shape: (600, 18)
#
# First 5 rows of the merged DataFrame:
#                      id_x                        name  \
# 0  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 1  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 2  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 3  CG0qu39ItRcAd8J5liITYQ                  Elias Pita
# 4  CG0qu39ItRcAd8J5liITYQ                  Elias Pita
#
#                                                url_x  \
# 0  https://www.yelp.com/biz/smoke-and-fire-social...
# 1  https://www.yelp.com/biz/smoke-and-fire-social...
# 2  https://www.yelp.com/biz/smoke-and-fire-social...
# 3  https://www.yelp.com/biz/elias-pita-riverside?...
# 4  https://www.yelp.com/biz/elias-pita-riverside?...
#
#                                           categories  rating_x  \
# 0  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...       4.5
# 1  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...       4.5
# 2  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...       4.5
# 3  [{'alias': 'mediterranean', 'title': 'Mediterr...       4.3
# 4  [{'alias': 'mediterranean', 'title': 'Mediterr...       4.3
#
#                                          coordinates price  \
# 0  {'latitude': 33.955971, 'longitude': -117.330408}    $$
# 1  {'latitude': 33.955971, 'longitude': -117.330408}    $$
# 2  {'latitude': 33.955971, 'longitude': -117.330408}    $$
# 3    {'latitude': 33.97533, 'longitude': -117.34385}    $$
# 4    {'latitude': 33.97533, 'longitude': -117.34385}    $$
#
#                                             location         phone  \
# 0  {'address1': '5225 Canyon Crest Dr', 'address2...  +19517427309
# 1  {'address1': '5225 Canyon Crest Dr', 'address2...  +19517427309
# 2  {'address1': '5225 Canyon Crest Dr', 'address2...  +19517427309
# 3  {'address1': '1490 University Ave', 'address2'...  +19516866800
# 4  {'address1': '1490 University Ave', 'address2'...  +19516866800
#
#       distance                                     business_hours  \
# 0  2642.903707  [{'open': [{'is_overnight': False, 'start': '1...
# 1  2642.903707  [{'open': [{'is_overnight': False, 'start': '1...
# 2  2642.903707  [{'open': [{'is_overnight': False, 'start': '1...
# 3  1509.822879  [{'open': [{'is_overnight': False, 'start': '1...
# 4  1509.822879  [{'open': [{'is_overnight': False, 'start': '1...
#
#                      id_y                                              url_y  \
# 0  e84DJb5bqU63D-7cObU4pQ  https://www.yelp.com/biz/smoke-and-fire-social...
# 1  rWQ-KpfjLDTBes6LarDuhg  https://www.yelp.com/biz/smoke-and-fire-social...
# 2  O3Rnl2Ew8uulDA_TBPTDtA  https://www.yelp.com/biz/smoke-and-fire-social...
# 3  UV3u1IbW-q38XWgTZgRdnQ  https://www.yelp.com/biz/elias-pita-riverside?...
# 4  43QScRvU-r0NLjt-dzG5WQ  https://www.yelp.com/biz/elias-pita-riverside?...
#
#                                                 text  rating_y  \
# 0  Food was good, service was great, Alexa was ve...         4
# 1  Absolutely love the atmosphere and the food is...         5
# 2  They ran out of fries and coleslaw and still c...         3
# 3  Excellent + food was delicious, great portion,...         5
# 4  The food was amazing! We had the gyro's and hu...         5
#
#           time_created                                               user  \
# 0  2025-04-05 12:27:18  {'id': 'KcxN-hBjh7OsdQJh_0xvWA', 'profile_url'...
# 1  2025-03-23 21:16:35  {'id': 'DJDC7kwj4qItmsi5BXWC8A', 'profile_url'...
# 2  2025-03-03 03:39:00  {'id': 'S3gYxVAwJcGy76e3gdJZBg', 'profile_url'...
# 3  2025-04-06 11:01:58  {'id': 'kQKosEedp_QFSZS7wyB3Og', 'profile_url'...
# 4  2024-11-08 15:17:32  {'id': 'ORK17DiBQHAmLYdEjzsnJQ', 'profile_url'...
#
#               business_id
# 0  7XJsjflQAnQTzvQYzAwydA
# 1  7XJsjflQAnQTzvQYzAwydA
# 2  7XJsjflQAnQTzvQYzAwydA
# 3  CG0qu39ItRcAd8J5liITYQ
# 4  CG0qu39ItRcAd8J5liITYQ

# %% [raw]
# restaurant_reviews_df.head()

# %%
restaurant_reviews_df.head()
# Out:
#                      id_x                        name  \
# 0  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 1  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 2  7XJsjflQAnQTzvQYzAwydA  Smoke & Fire Social Eatery
# 3  CG0qu39ItRcAd8J5liITYQ                  Elias Pita
# 4  CG0qu39ItRcAd8J5liITYQ                  Elias Pita
#
#                                                url_x  \
# 0  https://www.yelp.com/biz/smoke-and-fire-social...
# 1  https://www.yelp.com/biz/smoke-and-fire-social...
# 2  https://www.yelp.com/biz/smoke-and-fire-social...
# 3  https://www.yelp.com/biz/elias-pita-riverside?...
# 4  https://www.yelp.com/biz/elias-pita-riverside?...
#
#                                           categories  rating_x  \
# 0  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...       4.5
# 1  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...       4.5
# 2  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...       4.5
# 3  [{'alias': 'mediterranean', 'title': 'Mediterr...       4.3
# 4  [{'alias': 'mediterranean', 'title': 'Mediterr...       4.3
#
#                                          coordinates price  \
# 0  {'latitude': 33.955971, 'longitude': -117.330408}    $$
# 1  {'latitude': 33.955971, 'longitude': -117.330408}    $$
# 2  {'latitude': 33.955971, 'longitude': -117.330408}    $$
# 3    {'latitude': 33.97533, 'longitude': -117.34385}    $$
# 4    {'latitude': 33.97533, 'longitude': -117.34385}    $$
#
#                                             location         phone  \
# 0  {'address1': '5225 Canyon Crest Dr', 'address2...  +19517427309
# 1  {'address1': '5225 Canyon Crest Dr', 'address2...  +19517427309
# 2  {'address1': '5225 Canyon Crest Dr', 'address2...  +19517427309
# 3  {'address1': '1490 University Ave', 'address2'...  +19516866800
# 4  {'address1': '1490 University Ave', 'address2'...  +19516866800
#
#       distance                                     business_hours  \
# 0  2642.903707  [{'open': [{'is_overnight': False, 'start': '1...
# 1  2642.903707  [{'open': [{'is_overnight': False, 'start': '1...
# 2  2642.903707  [{'open': [{'is_overnight': False, 'start': '1...
# 3  1509.822879  [{'open': [{'is_overnight': False, 'start': '1...
# 4  1509.822879  [{'open': [{'is_overnight': False, 'start': '1...
#
#                      id_y                                              url_y  \
# 0  e84DJb5bqU63D-7cObU4pQ  https://www.yelp.com/biz/smoke-and-fire-social...
# 1  rWQ-KpfjLDTBes6LarDuhg  https://www.yelp.com/biz/smoke-and-fire-social...
# 2  O3Rnl2Ew8uulDA_TBPTDtA  https://www.yelp.com/biz/smoke-and-fire-social...
# 3  UV3u1IbW-q38XWgTZgRdnQ  https://www.yelp.com/biz/elias-pita-riverside?...
# 4  43QScRvU-r0NLjt-dzG5WQ  https://www.yelp.com/biz/elias-pita-riverside?...
#
#                                                 text  rating_y  \
# 0  Food was good, service was great, Alexa was ve...         4
# 1  Absolutely love the atmosphere and the food is...         5
# 2  They ran out of fries and coleslaw and still c...         3
# 3  Excellent + food was delicious, great portion,...         5
# 4  The food was amazing! We had the gyro's and hu...         5
#
#           time_created                                               user  \
# 0  2025-04-05 12:27:18  {'id': 'KcxN-hBjh7OsdQJh_0xvWA', 'profile_url'...
# 1  2025-03-23 21:16:35  {'id': 'DJDC7kwj4qItmsi5BXWC8A', 'profile_url'...
# 2  2025-03-03 03:39:00  {'id': 'S3gYxVAwJcGy76e3gdJZBg', 'profile_url'...
# 3  2025-04-06 11:01:58  {'id': 'kQKosEedp_QFSZS7wyB3Og', 'profile_url'...
# 4  2024-11-08 15:17:32  {'id': 'ORK17DiBQHAmLYdEjzsnJQ', 'profile_url'...
#
#               business_id
# 0  7XJsjflQAnQTzvQYzAwydA
# 1  7XJsjflQAnQTzvQYzAwydA
# 2  7XJsjflQAnQTzvQYzAwydA
# 3  CG0qu39ItRcAd8J5liITYQ
# 4  CG0qu39ItRcAd8J5liITYQ

# %%
if not restaurants_df.empty and not reviews_df.empty:
    # Group reviews by business_id and aggregate review texts into a list
    restaurant_review_texts = reviews_df.groupby('business_id')['text'].agg(list).reset_index()

    # Rename the columns for clarity during the merge
    restaurant_review_texts.rename(columns={'business_id': 'id', 'text': 'review_texts'}, inplace=True)

    # Merge the review texts back into the restaurants_df
    restaurants_df = pd.merge(restaurants_df, restaurant_review_texts, on='id', how='left')

    print("\nFirst 5 rows of the restaurants DataFrame with review texts:")
    print(restaurants_df[['id', 'name', 'review_texts']].head())
else:
    print("\nRestaurants or reviews DataFrame is empty.")
# Out:
# First 5 rows of the restaurants DataFrame with review texts:
#                        id                             name  \
# 0  7XJsjflQAnQTzvQYzAwydA       Smoke & Fire Social Eatery
# 1  CG0qu39ItRcAd8J5liITYQ                       Elias Pita
# 2  ElH8ZbPSG1rIFA3wXyFn5Q                   The Salted Pig
# 3  KIVSXV1MrwIUO8E02M0H6Q                Craving Crab Haus
# 4  wsgdv_edV5bvssYk9pyOIg  Georgie’s Mediterranean Cuisine
#
#                                         review_texts
# 0  [Food was good, service was great, Alexa was v...
# 1  [Excellent + food was delicious, great portion...
# 2  [The Salted Pig has always been a special spot...
# 3  [this is the most amazing delicious and custom...
# 4  [The food is great, they have good portions! I...

# %% [raw]
# restaurants_df.head()

# %%
restaurants_df['categories'].head()
# Out:
# 0    [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...
# 1    [{'alias': 'mediterranean', 'title': 'Mediterr...
# 2    [{'alias': 'gastropubs', 'title': 'Gastropubs'...
# 3    [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...
# 4    [{'alias': 'mediterranean', 'title': 'Mediterr...
# Name: categories, dtype: object

# %%
def clean_categories_alias(categories_list):
    """
    Cleans the categories data to be a list of aliases.
    """
    if isinstance(categories_list, list):
        return [cat['alias'] for cat in categories_list if isinstance(cat, dict) and 'alias' in cat]
    return []

# %%
restaurants_df['categories_cleaned_alias'] = restaurants_df['categories'].apply(clean_categories_alias)

# %%
# Drop the original 'categories' column
restaurants_df.drop(columns=['categories'], inplace=True)

# Rename the 'categories_cleaned_alias' column to 'categories'
restaurants_df.rename(columns={'categories_cleaned_alias': 'categories'}, inplace=True)

# Display the DataFrame with the renamed and dropped columns
print(restaurants_df[['name', 'categories']].head())
# Out:
#                               name  \
# 0       Smoke & Fire Social Eatery
# 1                       Elias Pita
# 2                   The Salted Pig
# 3                Craving Crab Haus
# 4  Georgie’s Mediterranean Cuisine
#
#                                     categories
# 0             [bbq, tradamerican, comfortfood]
# 1           [mediterranean, mideastern, halal]
# 2  [gastropubs, newamerican, breakfast_brunch]
# 3                 [cajun, sportsbars, seafood]
# 4                  [mediterranean, mideastern]

# %%
restaurants_df.head()
# Out:
#                        id                                      alias  \
# 0  7XJsjflQAnQTzvQYzAwydA   smoke-and-fire-social-eatery-riverside-2
# 1  CG0qu39ItRcAd8J5liITYQ                       elias-pita-riverside
# 2  ElH8ZbPSG1rIFA3wXyFn5Q                   the-salted-pig-riverside
# 3  KIVSXV1MrwIUO8E02M0H6Q                craving-crab-haus-riverside
# 4  wsgdv_edV5bvssYk9pyOIg  georgie-s-mediterranean-cuisine-riverside
#
#                               name  \
# 0       Smoke & Fire Social Eatery
# 1                       Elias Pita
# 2                   The Salted Pig
# 3                Craving Crab Haus
# 4  Georgie’s Mediterranean Cuisine
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/_n6TU4...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/G65RHz...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/blk-Vh...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/3WhUY5...      False
#
#                                                  url  review_count  rating  \
# 0  https://www.yelp.com/biz/smoke-and-fire-social...          2672     4.5
# 1  https://www.yelp.com/biz/elias-pita-riverside?...          1160     4.3
# 2  https://www.yelp.com/biz/the-salted-pig-rivers...          3349     3.8
# 3  https://www.yelp.com/biz/craving-crab-haus-riv...           427     4.5
# 4  https://www.yelp.com/biz/georgie-s-mediterrane...           426     4.5
#
#                                          coordinates  \
# 0  {'latitude': 33.955971, 'longitude': -117.330408}
# 1    {'latitude': 33.97533, 'longitude': -117.34385}
# 2    {'latitude': 33.98226, 'longitude': -117.37386}
# 3    {'latitude': 33.97674, 'longitude': -117.33752}
# 4  {'latitude': 33.95623720813322, 'longitude': -...
#
#                transactions price  \
# 0                        []    $$
# 1        [delivery, pickup]    $$
# 2                [delivery]    $$
# 3  [restaurant_reservation]    $$
# 4        [delivery, pickup]    $$
#
#                                             location         phone  \
# 0  {'address1': '5225 Canyon Crest Dr', 'address2...  +19517427309
# 1  {'address1': '1490 University Ave', 'address2'...  +19516866800
# 2  {'address1': '3750 Main St', 'address2': 'Ste ...  +19517425664
# 3  {'address1': '1201 University Ave', 'address2'...  +19517425859
# 4  {'address1': '5225 Canyon Crest Dr', 'address2...  +19518230440
#
#     display_phone     distance  \
# 0  (951) 742-7309  2642.903707
# 1  (951) 686-6800  1509.822879
# 2  (951) 742-5664  4243.221458
# 3  (951) 742-5859   904.674919
# 4  (951) 823-0440  2547.020308
#
#                                       business_hours  \
# 0  [{'open': [{'is_overnight': False, 'start': '1...
# 1  [{'open': [{'is_overnight': False, 'start': '1...
# 2  [{'open': [{'is_overnight': False, 'start': '1...
# 3  [{'open': [{'is_overnight': False, 'start': '1...
# 4  [{'open': [{'is_overnight': False, 'start': '1...
#
#                                           attributes  \
# 0  {'business_accepts_android_pay': True, 'busine...
# 1  {'business_accepts_android_pay': True, 'busine...
# 2  {'business_accepts_android_pay': True, 'busine...
# 3  {'has_pool_table': False, 'business_url': 'htt...
# 4  {'business_url': 'https://georgiesmediterranea...
#
#                                          description  \
# 0  Description not available. Showing name: Smoke...
# 1  Description not available. Showing name: Elias...
# 2  Description not available. Showing name: The S...
# 3  Description not available. Showing name: Cravi...
# 4  Description not available. Showing name: Georg...
#
#                                         review_texts  \
# 0  [Food was good, service was great, Alexa was v...
# 1  [Excellent + food was delicious, great portion...
# 2  [The Salted Pig has always been a special spot...
# 3  [this is the most amazing delicious and custom...
# 4  [The food is great, they have good portions! I...
#
#                                     categories
# 0             [bbq, tradamerican, comfortfood]
# 1           [mediterranean, mideastern, halal]
# 2  [gastropubs, newamerican, breakfast_brunch]
# 3                 [cajun, sportsbars, seafood]
# 4                  [mediterranean, mideastern]

# %%
restaurants_df['attributes']
# Out:
# 0      {'business_accepts_android_pay': True, 'busine...
# 1      {'business_accepts_android_pay': True, 'busine...
# 2      {'business_accepts_android_pay': True, 'busine...
# 3      {'has_pool_table': False, 'business_url': 'htt...
# 4      {'business_url': 'https://georgiesmediterranea...
#                              ...
# 195    {'business_accepts_android_pay': True, 'busine...
# 196    {'business_url': None, 'about_this_biz_bio_pho...
# 197    {'business_accepts_android_pay': True, 'busine...
# 198    {'business_accepts_android_pay': True, 'busine...
# 199    {'business_accepts_apple_pay': False, 'busines...
# Name: attributes, Length: 200, dtype: object

# %%
print(restaurants_df.head(1))
# Out:
#                        id                                     alias  \
# 0  7XJsjflQAnQTzvQYzAwydA  smoke-and-fire-social-eatery-riverside-2
#
#                          name  \
# 0  Smoke & Fire Social Eatery
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj...      False
#
#                                                  url  review_count  rating  \
# 0  https://www.yelp.com/biz/smoke-and-fire-social...          2672     4.5
#
#                                          coordinates transactions price  \
# 0  {'latitude': 33.955971, 'longitude': -117.330408}           []    $$
#
#                                             location         phone  \
# 0  {'address1': '5225 Canyon Crest Dr', 'address2...  +19517427309
#
#     display_phone     distance  \
# 0  (951) 742-7309  2642.903707
#
#                                       business_hours  \
# 0  [{'open': [{'is_overnight': False, 'start': '1...
#
#                                           attributes  \
# 0  {'business_accepts_android_pay': True, 'busine...
#
#                                          description  \
# 0  Description not available. Showing name: Smoke...
#
#                                         review_texts  \
# 0  [Food was good, service was great, Alexa was v...
#
#                          categories
# 0  [bbq, tradamerican, comfortfood]

# %%
pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from datasets) (1.24.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp38-cp38-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.32.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp38-cp38-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py38-none-any.whl.metadata (7.1 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.10.11-cp38-cp38-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting huggingface-hub>=0.23.0 (from datasets)
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from datasets) (6.0.1)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets)
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from aiohttp->datasets) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.5.0-cp38-cp38-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.1.0-cp38-cp38-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Collecting yarl<2.0,>=1.12.0 (from aiohttp->datasets)
#   Downloading yarl-1.15.2-cp38-cp38-macosx_11_0_arm64.whl.metadata (56 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp->datasets)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Collecting propcache>=0.2.0 (from yarl<2.0,>=1.12.0->aiohttp->datasets)
#   Downloading propcache-0.2.0-cp38-cp38-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Downloading aiohttp-3.10.11-cp38-cp38-macosx_11_0_arm64.whl (394 kB)
# Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Downloading multiprocess-0.70.16-py38-none-any.whl (132 kB)
# Downloading pyarrow-17.0.0-cp38-cp38-macosx_11_0_arm64.whl (27.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.2/27.2 MB 16.3 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading xxhash-3.5.0-cp38-cp38-macosx_11_0_arm64.whl (30 kB)
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading frozenlist-1.5.0-cp38-cp38-macosx_11_0_arm64.whl (52 kB)
# Downloading multidict-6.1.0-cp38-cp38-macosx_11_0_arm64.whl (29 kB)
# Downloading yarl-1.15.2-cp38-cp38-macosx_11_0_arm64.whl (87 kB)
# Downloading propcache-0.2.0-cp38-cp38-macosx_11_0_arm64.whl (46 kB)
# Installing collected packages: xxhash, pyarrow, propcache, multidict, fsspec, frozenlist, dill, async-timeout, aiohappyeyeballs, yarl, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
# Successfully installed aiohappyeyeballs-2.4.4 aiohttp-3.10.11 aiosignal-1.3.1 async-timeout-5.0.1 datasets-3.1.0 dill-0.3.8 frozenlist-1.5.0 fsspec-2024.9.0 huggingface-hub-0.30.2 multidict-6.1.0 multiprocess-0.70.16 propcache-0.2.0 pyarrow-17.0.0 xxhash-3.5.0 yarl-1.15.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import Dataset

# %%
def create_full_detail_dataset(restaurants_df):
    """
    Creates a dataset for fine-tuning a model to generate restaurant descriptions
    using all available fields within the 'input' text.
    """
    data = []
    for index, row in restaurants_df.iterrows():
        if row['review_texts']:
            restaurant_info = {col: row[col] for col in restaurants_df.columns}
            input_text = f"Restaurant details: {json.dumps(restaurant_info, default=str)}. Reviews: {', '.join(row['review_texts'][:5])}"

            output_text = f"A restaurant named {row['name']} serving {row['categories']} in {row['location']['city']}." # Example - improve this!

            data.append({
                'instruction': "Generate a short description for this restaurant based on all its available details and reviews.",
                'input': input_text,
                'output': output_text
            })
    return Dataset.from_pandas(pd.DataFrame(data))

# %%
full_detail_dataset = create_full_detail_dataset(restaurants_df)

# %%
print(full_detail_dataset[0])
# Out:
# {'instruction': 'Generate a short description for this restaurant based on all its available details and reviews.', 'input': 'Restaurant details: {"id": "7XJsjflQAnQTzvQYzAwydA", "alias": "smoke-and-fire-social-eatery-riverside-2", "name": "Smoke & Fire Social Eatery", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj4G_U2mlY1VRyJJtg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/smoke-and-fire-social-eatery-riverside-2?adjust_creative=s2u-5RnsfwMJeHOvze7LIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=s2u-5RnsfwMJeHOvze7LIQ", "review_count": 2672, "rating": 4.5, "coordinates": {"latitude": 33.955971, "longitude": -117.330408}, "transactions": [], "price": "$$", "location": {"address1": "5225 Canyon Crest Dr", "address2": "Unit 9", "address3": "", "city": "Riverside", "zip_code": "92507", "country": "US", "state": "CA", "display_address": ["5225 Canyon Crest Dr", "Unit 9", "Riverside, CA 92507"]}, "phone": "+19517427309", "display_phone": "(951) 742-7309", "distance": 2642.903706787673, "business_hours": [{"open": [{"is_overnight": false, "start": "1000", "end": "2200", "day": 0}, {"is_overnight": false, "start": "1000", "end": "2200", "day": 1}, {"is_overnight": false, "start": "1000", "end": "2200", "day": 2}, {"is_overnight": false, "start": "1000", "end": "2200", "day": 3}, {"is_overnight": false, "start": "1000", "end": "2200", "day": 4}, {"is_overnight": false, "start": "1000", "end": "2200", "day": 5}, {"is_overnight": false, "start": "1000", "end": "2200", "day": 6}], "hours_type": "REGULAR", "is_open_now": true}], "attributes": {"business_accepts_android_pay": true, "business_accepts_apple_pay": true, "business_url": "http://www.thesmokeandfire.com", "about_this_biz_bio_photo_dict": null, "about_this_biz_business_recommendation": [], "business_temp_closed": null, "about_this_biz_bio": null, "about_this_biz_bio_first_name": null, "about_this_biz_bio_last_name": null, "about_this_biz_history": null, "about_this_biz_role": null, "about_this_biz_specialties": "Join us for our new Wing Menu rollout! Come try the 3 hottest flavors you can find. We\'re also now serving Brunch Thursday - Sunday 10am - 1pm.", "about_this_biz_year_established": null, "alcohol": "beer_and_wine", "ambience": {"divey": false, "hipster": null, "casual": true, "touristy": null, "trendy": true, "intimate": false, "romantic": false, "classy": null, "upscale": null}, "bike_parking": true, "business_accepts_credit_cards": true, "business_parking": {"valet": false, "garage": false, "street": false, "lot": true, "validated": false}, "caters": true, "dogs_allowed": true, "drive_thru": false, "good_for_kids": true, "good_for_meal": {"breakfast": null, "brunch": true, "lunch": true, "dinner": true, "latenight": null, "dessert": true}, "happy_hour": true, "has_tv": true, "menu_url": "https://www.thesmokeandfire.com/menu", "noise_level": "average", "open24_hours": null, "platform_delivery": null, "restaurants_delivery": true, "restaurants_good_for_groups": true, "restaurants_reservations": false, "restaurants_table_service": false, "restaurants_take_out": true, "waitlist_reservation": null, "wi_fi": "no", "liked_by_vegans": true, "outdoor_seating": true, "liked_by_vegetarians": null, "hot_and_new": null}, "description": "Description not available. Showing name: Smoke & Fire Social Eatery", "review_texts": ["Food was good, service was great, Alexa was very helpful and the environmental atmosphere was superb!.", "Absolutely love the atmosphere and the food is beyond delicious! I come for happy hour regularly and love the service I get! Nour is SUPER attentive and...", "They ran out of fries and coleslaw and still charged normally for all items including them along with a random service fee. Atmosphere was fine and staff..."], "categories": ["bbq", "tradamerican", "comfortfood"]}. Reviews: Food was good, service was great, Alexa was very helpful and the environmental atmosphere was superb!., Absolutely love the at ...

# %%
def save_dataset_as_jsonl(dataset, filepath):
    """Saves a Hugging Face Dataset as a JSON Lines file."""
    with open(filepath, 'w', encoding='utf-8') as f:
        for item in dataset:
            json.dump(item, f, ensure_ascii=False)
            f.write('\n')

# Save the dataset as JSON Lines
save_dataset_as_jsonl(full_detail_dataset, 'restaurant_dataset.jsonl')
print("Dataset saved to restaurant_dataset.jsonl")
# Out:
# Dataset saved to restaurant_dataset.jsonl

# %%
from datasets import Dataset
import pandas as pd
import json
from collections import defaultdict

def create_descriptive_output_dataset_from_dataset(full_detail_dataset):
    """
    Creates a dataset for fine-tuning a model where the output is a natural
    language description, using the full_detail_dataset as input.
    """
    data = []
    for item in full_detail_dataset:
        if item.get('input'):
            restaurant_details = {}
            try:
                restaurant_info_json = item['input'].split('Restaurant details: ')[1].split('. Reviews:')[0]
                restaurant_details = json.loads(restaurant_info_json)
            except (KeyError, json.JSONDecodeError, IndexError) as e:
                print(f"Error processing item: {item.get('name', 'Unknown')}. Error: {e}")
                continue

            name = restaurant_details.get('name', 'This restaurant')
            categories = restaurant_details.get('categories', [])
            attributes = restaurant_details.get('attributes', {})
            reviews = restaurant_details.get('review_texts', [])

            output_parts = [f"This restaurant {name}"]

            if categories:
                output_parts.append(f"is a {', '.join(categories)} restaurant")

            
            if attributes['ambience'] is not None:
                ambience_str = ", ".join([k.replace('_', ' ') for k, v in attributes.get('ambience', {}).items() if v == True])
                output_parts.append(f"with a {ambience_str} ambiance")

            
            if attributes['good_for_meal'] is not None:
                good_for_meal = ", ".join([k.title() for k, v in attributes.get('good_for_meal', {}).items() if v == True])
                output_parts.append(f"that's good for {good_for_meal}")

            price = restaurant_details.get('price')
            if price:
                output_parts.append(f"and has a price range of {price}")

            takeout = attributes.get('restaurants_take_out')
            if takeout:
                output_parts.append("offering takeout")

            delivery = attributes.get('restaurants_delivery')
            if delivery:
                output_parts.append("offering delivery")

            kid_friendly = attributes.get('good_for_kids')
            if kid_friendly:
                output_parts.append("that's kid-friendly")

            review_summary = ". Customers say"
            for review in reviews:
                review_summary += ", " + review
            output_parts.append(review_summary)
            output_text = " ".join(output_parts)

            data.append({
                'instruction': item['instruction'],
                'input': item['input'],
                'output': output_text.strip()
            })
    return Dataset.from_pandas(pd.DataFrame(data))

# Create the dataset with detailed descriptive outputs using the in-memory dataset
detailed_output_dataset = create_descriptive_output_dataset_from_dataset(full_detail_dataset)
print(f"Length of full_detail_dataset: {len(full_detail_dataset)}")

print(detailed_output_dataset[0])
# Out:
# Length of full_detail_dataset: 200
# {'instruction': 'Generate a short description for this restaurant based on all its available details and reviews.', 'input': 'Restaurant details: {"id": "7XJsjflQAnQTzvQYzAwydA", "alias": "smoke-and-fire-social-eatery-riverside-2", "name": "Smoke & Fire Social Eatery", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/vGyDDj4G_U2mlY1VRyJJtg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/smoke-and-fire-social-eatery-riverside-2?adjust_creative=s2u-5RnsfwMJeHOvze7LIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=s2u-5RnsfwMJeHOvze7LIQ", "review_count": 2672, "rating": 4.5, "coordinates": {"latitude": 33.955971, "longitude": -117.330408}, "transactions": [], "price": "$$", "location": {"address1": "5225 Canyon Crest Dr", "address2": "Unit 9", "address3": "", "city": "Riverside", "zip_code": "92507", "country": "US", "state": "CA", "display_address": ["5225 Canyon Crest Dr", "Unit 9", "Riverside, CA 92507"]}, "phone": "+19517427309", "display_phone": "(951) 742-7309", "distance": 2642.903706787673, "business_hours": [{"open": [{"is_overnight": false, "start": "1000", "end": "2200", "day": 0}, {"is_overnight": false, "start": "1000", "end": "2200", "day": 1}, {"is_overnight": false, "start": "1000", "end": "2200", "day": 2}, {"is_overnight": false, "start": "1000", "end": "2200", "day": 3}, {"is_overnight": false, "start": "1000", "end": "2200", "day": 4}, {"is_overnight": false, "start": "1000", "end": "2200", "day": 5}, {"is_overnight": false, "start": "1000", "end": "2200", "day": 6}], "hours_type": "REGULAR", "is_open_now": true}], "attributes": {"business_accepts_android_pay": true, "business_accepts_apple_pay": true, "business_url": "http://www.thesmokeandfire.com", "about_this_biz_bio_photo_dict": null, "about_this_biz_business_recommendation": [], "business_temp_closed": null, "about_this_biz_bio": null, "about_this_biz_bio_first_name": null, "about_this_biz_bio_last_name": null, "about_this_biz_history": null, "about_this_biz_role": null, "about_this_biz_specialties": "Join us for our new Wing Menu rollout! Come try the 3 hottest flavors you can find. We\'re also now serving Brunch Thursday - Sunday 10am - 1pm.", "about_this_biz_year_established": null, "alcohol": "beer_and_wine", "ambience": {"divey": false, "hipster": null, "casual": true, "touristy": null, "trendy": true, "intimate": false, "romantic": false, "classy": null, "upscale": null}, "bike_parking": true, "business_accepts_credit_cards": true, "business_parking": {"valet": false, "garage": false, "street": false, "lot": true, "validated": false}, "caters": true, "dogs_allowed": true, "drive_thru": false, "good_for_kids": true, "good_for_meal": {"breakfast": null, "brunch": true, "lunch": true, "dinner": true, "latenight": null, "dessert": true}, "happy_hour": true, "has_tv": true, "menu_url": "https://www.thesmokeandfire.com/menu", "noise_level": "average", "open24_hours": null, "platform_delivery": null, "restaurants_delivery": true, "restaurants_good_for_groups": true, "restaurants_reservations": false, "restaurants_table_service": false, "restaurants_take_out": true, "waitlist_reservation": null, "wi_fi": "no", "liked_by_vegans": true, "outdoor_seating": true, "liked_by_vegetarians": null, "hot_and_new": null}, "description": "Description not available. Showing name: Smoke & Fire Social Eatery", "review_texts": ["Food was good, service was great, Alexa was very helpful and the environmental atmosphere was superb!.", "Absolutely love the atmosphere and the food is beyond delicious! I come for happy hour regularly and love the service I get! Nour is SUPER attentive and...", "They ran out of fries and coleslaw and still charged normally for all items including them along with a random service fee. Atmosphere was fine and staff..."], "categories": ["bbq", "tradamerican", "comfortfood"]}. Reviews: Food was good, service was great, Alexa was very helpful and the environmental atmosphere was superb!., Absolutely love the at ...

# %%
from datasets import load_dataset

# %%
def save_dataset_as_jsonl(dataset, filepath):
    """Saves a Hugging Face Dataset as a JSON Lines file."""
    with open(filepath, 'w', encoding='utf-8') as f:
        for item in dataset:
            json.dump(item, f, ensure_ascii=False)
            f.write('\n')

# Save the dataset as JSON Lines
save_dataset_as_jsonl(detailed_output_dataset, 'restaurant_dataset.jsonl')
print("Dataset saved to restaurant_dataset.jsonl")
# Out:
# Dataset saved to restaurant_dataset.jsonl
